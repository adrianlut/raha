# %% [markdown]
# # End-to-End Data Cleaning Pipeline with Raha and Baran (Minimal and Sequential)
# We build an end-to-end data cleaning pipeline with our configuration-free error detection and correction systems, Raha and Baran.

# %%
import pandas
import IPython.display

import raha

# %% [markdown]
# ## Error Detection with Raha

# %% [markdown]
# ### 1. Instantiating the Detection Class
# We first instantiate the `Detection` class.

# %%
app_1 = raha.Detection()

# How many tuples would you label?
app_1.LABELING_BUDGET = 20

# Would you like to see the logs?
app_1.VERBOSE = True

# %% [markdown]
# ### 2. Instantiating the Dataset
# We next load and instantiate the dataset object.

# %%
dataset_dictionary = {
    "name": "flights",
    "path": "datasets/flights/dirty.csv",
    "clean_path": "datasets/flights/clean.csv"
}
d = app_1.initialize_dataset(dataset_dictionary)
d.dataframe.head()
# Out:
#   tuple_id src           flight sched_dep_time act_dep_time sched_arr_time  \
# 0        1  aa  AA-3859-IAH-ORD      7:10 a.m.    7:16 a.m.      9:40 a.m.
# 1        2  aa  AA-1733-ORD-PHX      7:45 p.m.    7:58 p.m.     10:30 p.m.
# 2        3  aa  AA-1640-MIA-MCO      6:30 p.m.                   7:25 p.m.
# 3        4  aa   AA-518-MIA-JFK      6:40 a.m.    6:54 a.m.      9:25 a.m.
# 4        5  aa  AA-3756-ORD-SLC     12:15 p.m.   12:41 p.m.      2:45 p.m.
#
#   act_arr_time
# 0    9:32 a.m.
# 1
# 2
# 3    9:28 a.m.
# 4    2:50 p.m.

# %% [markdown]
# ### 3. Running Error Detection Strategies
# Raha runs (all or the promising) error detection strategies on the dataset. This step could take a while because all the strategies should be run on the dataset.

# %%
app_1.run_strategies(d)
# Out:
# 72 cells are detected by ["PVD", ["sched_dep_time", "c"]].
# 92 cells are detected by ["PVD", ["src", "q"]].
#
# 76 cells are detected by ["PVD", ["act_arr_time", "i"]].17 cells are detected by ["PVD", ["sched_arr_time", "F"]].1593 cells are detected by ["PVD", ["sched_arr_time", ":"]].
#
# 16 cells are detected by ["PVD", ["sched_arr_time", "A"]].
# 1 cells are detected by ["PVD", ["act_arr_time", "\u00a0"]].
# 671 cells are detected by ["PVD", ["src", "s"]].
# 919 cells are detected by ["PVD", ["tuple_id", "2"]].
# 741 cells are detected by ["PVD", ["sched_arr_time", "0"]].55 cells are detected by ["PVD", ["src", "-"]].
#
# 43 cells are detected by ["PVD", ["act_arr_time", "r"]].
# 31 cells are detected by ["PVD", ["act_dep_time", "s"]].
# 145 cells are detected by ["PVD", ["flight", "V"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "b"]].7 cells are detected by ["PVD", ["sched_arr_time", "h"]].
#
# 279 cells are detected by ["PVD", ["flight", "K"]].
# 1426 cells are detected by ["PVD", ["tuple_id", "1"]].
# 117 cells are detected by ["PVD", ["sched_arr_time", "D"]].
# 616 cells are detected by ["PVD", ["tuple_id", "6"]].
#
# 616 cells are detected by ["PVD", ["tuple_id", "5"]].
# 283 cells are detected by ["PVD", ["flight", "T"]].874 cells are detected by ["PVD", ["flight", "H"]].86 cells are detected by ["PVD", ["flight", "B"]].
#
# 606 cells are detected by ["PVD", ["tuple_id", "9"]].
# 106 cells are detected by ["PVD", ["sched_arr_time", "8"]].
# 75 cells are detected by ["PVD", ["act_dep_time", "D"]].
# 1540 cells are detected by ["PVD", ["flight", "O"]].
# 32 cells are detected by ["PVD", ["act_arr_time", "o"]].
# 18 cells are detected by ["PVD", ["act_arr_time", "N"]].
# 405 cells are detected by ["PVD", ["act_arr_time", "6"]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "T"]].
# 163 cells are detected by ["PVD", ["flight", "N"]].
# 1525 cells are detected by ["PVD", ["sched_arr_time", "m"]].
# 2 cells are detected by ["PVD", ["act_arr_time", "F"]].30 cells are detected by ["PVD", ["sched_arr_time", "i"]].31 cells are detected by ["PVD", ["act_dep_time", "E"]].229 cells are detected by ["PVD", ["sched_arr_time", "7"]].
#
#
# 1518 cells are detected by ["PVD", ["src", "i"]].131 cells are detected by ["PVD", ["sched_dep_time", "9"]].
# 676 cells are detected by ["PVD", ["act_arr_time", "3"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "v"]].955 cells are detected by ["PVD", ["act_dep_time", "1"]].
#
# 764 cells are detected by ["PVD", ["act_dep_time", "2"]].770 cells are detected by ["PVD", ["sched_dep_time", "1"]].
#
#
# 638 cells are detected by ["PVD", ["act_arr_time", "2"]].
#
# 797 cells are detected by ["PVD", ["sched_dep_time", "p"]].
# 451 cells are detected by ["PVD", ["sched_arr_time", "3"]].2376 cells are detected by ["PVD", ["flight", "-"]].1375 cells are detected by ["PVD", ["src", "l"]].
#
# 13 cells are detected by ["PVD", ["sched_dep_time", "b"]].
#
# 956 cells are detected by ["PVD", ["act_arr_time", "1"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "N"]].
# 1 cells are detected by ["PVD", ["sched_dep_time", "h"]].952 cells are detected by ["PVD", ["flight", "I"]].
#
# 2 cells are detected by ["PVD", ["act_arr_time", "*"]].871 cells are detected by ["PVD", ["flight", "4"]].
#
# 1503 cells are detected by ["PVD", ["sched_dep_time", "."]].
# 1910 cells are detected by ["PVD", ["act_arr_time", "m"]].
# 3108 cells are detected by ["RVD", ["sched_arr_time", "src"]].3852 cells are detected by ["RVD", ["act_dep_time", "tuple_id"]].
# 0 cells are detected by ["RVD", ["tuple_id", "sched_dep_time"]].
#
# 745 cells are detected by ["PVD", ["src", "h"]].
# 258 cells are detected by ["PVD", ["act_dep_time", "9"]].23 cells are detected by ["PVD", ["sched_arr_time", "/"]].
# 2 cells are detected by ["PVD", ["sched_dep_time", "n"]].4210 cells are detected by ["RVD", ["flight", "sched_arr_time"]].
# 18 cells are detected by ["PVD", ["act_dep_time", "N"]].
#
#
# 263 cells are detected by ["PVD", ["src", "x"]].591 cells are detected by ["PVD", ["act_arr_time", "4"]].2830 cells are detected by ["RVD", ["sched_dep_time", "act_arr_time"]].473 cells are detected by ["PVD", ["act_dep_time", "8"]].
#
#
#
# 2 cells are detected by ["PVD", ["sched_arr_time", "P"]].613 cells are detected by ["PVD", ["tuple_id", "7"]].
# 4 cells are detected by ["PVD", ["sched_dep_time", "("]].
# 0 cells are detected by ["RVD", ["tuple_id", "sched_arr_time"]].18 cells are detected by ["PVD", ["act_dep_time", "v"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "t"]].
#
# 709 cells are detected by ["PVD", ["flight", "M"]].
#
# 1606 cells are detected by ["PVD", ["sched_arr_time", " "]].
# 1141 cells are detected by ["PVD", ["src", "r"]].
# 139 cells are detected by ["PVD", ["act_dep_time", "e"]].
# 732 cells are detected by ["PVD", ["flight", "F"]].0 cells are detected by ["RVD", ["tuple_id", "act_arr_time"]].
# 628 cells are detected by ["PVD", ["flight", "6"]].
# 383 cells are detected by ["PVD", ["act_dep_time", "6"]].
#
# 29 cells are detected by ["PVD", ["act_dep_time", "y"]].
# 791 cells are detected by ["PVD", ["sched_dep_time", "a"]].
# 1118 cells are detected by ["PVD", ["act_dep_time", "a"]].
# 2978 cells are detected by ["RVD", ["act_dep_time", "act_arr_time"]].
# 1110 cells are detected by ["RVD", ["sched_dep_time", "flight"]].3232 cells are detected by ["RVD", ["flight", "sched_dep_time"]].
# 539 cells are detected by ["PVD", ["flight", "0"]].
#
# 547 cells are detected by ["PVD", ["flight", "7"]].352 cells are detected by ["PVD", ["sched_dep_time", "3"]].
#
# 36 cells are detected by ["PVD", ["act_dep_time", "d"]].
# 48 cells are detected by ["PVD", ["act_arr_time", ")"]].
# 220 cells are detected by ["PVD", ["act_arr_time", "8"]].
# 729 cells are detected by ["PVD", ["sched_arr_time", "1"]].
# 32 cells are detected by ["PVD", ["act_dep_time", "A"]].
# 3585 cells are detected by ["OD", ["gaussian", "1.3"]].
# 357 cells are detected by ["OD", ["gaussian", "2.5"]].
# 61 cells are detected by ["PVD", ["act_arr_time", "c"]].
# 470 cells are detected by ["PVD", ["act_arr_time", "9"]].
# 627 cells are detected by ["PVD", ["sched_arr_time", "a"]].
# 794 cells are detected by ["OD", ["gaussian", "2.3"]].967 cells are detected by ["PVD", ["sched_arr_time", "p"]].
#
# 248 cells are detected by ["OD", ["gaussian", "3.0"]].409 cells are detected by ["PVD", ["sched_dep_time", "2"]].99 cells are detected by ["PVD", ["src", "z"]].
#
#
# 4752 cells are detected by ["RVD", ["flight", "tuple_id"]].476 cells are detected by ["PVD", ["act_dep_time", "7"]].498 cells are detected by ["PVD", ["flight", "P"]].1989 cells are detected by ["PVD", ["act_arr_time", " "]].
#
# 7 cells are detected by ["PVD", ["sched_arr_time", "T"]].
#
#
# 1205 cells are detected by ["PVD", ["src", "o"]].20 cells are detected by ["PVD", ["sched_arr_time", "-"]].
# 590 cells are detected by ["PVD", ["flight", "X"]].
# 542 cells are detected by ["PVD", ["src", "u"]].
# 1962 cells are detected by ["PVD", ["act_arr_time", ":"]].
#
# 6 cells are detected by ["PVD", ["act_arr_time", "T"]].117 cells are detected by ["PVD", ["sched_arr_time", "c"]].
# 13 cells are detected by ["PVD", ["sched_arr_time", "o"]].
# 506 cells are detected by ["PVD", ["flight", "S"]].
# 399 cells are detected by ["PVD", ["src", "w"]].
#
# 39 cells are detected by ["PVD", ["flight", "Y"]].
# 9566 cells are detected by ["OD", ["histogram", "0.9", "0.7"]].
# 602 cells are detected by ["PVD", ["act_dep_time", "4"]].13 cells are detected by ["PVD", ["sched_arr_time", "l"]].
#
# 796 cells are detected by ["PVD", ["flight", "1"]].3 cells are detected by ["PVD", ["act_arr_time", "R"]].495 cells are detected by ["PVD", ["flight", "9"]].
#
#
# 689 cells are detected by ["PVD", ["flight", "U"]].637 cells are detected by ["PVD", ["act_dep_time", "0"]].
#
# 4752 cells are detected by ["RVD", ["flight", "src"]].
# 12412 cells are detected by ["OD", ["histogram", "0.7", "0.7"]].
# 85 cells are detected by ["PVD", ["sched_dep_time", "e"]].1579 cells are detected by ["PVD", ["sched_dep_time", ":"]].1393 cells are detected by ["PVD", ["src", "e"]].
#
# 1503 cells are detected by ["PVD", ["sched_dep_time", "m"]].
#
# 399 cells are detected by ["PVD", ["src", "b"]].14 cells are detected by ["PVD", ["act_arr_time", "C"]].
#
# 4367 cells are detected by ["OD", ["histogram", "0.7", "0.3"]].1106 cells are detected by ["PVD", ["flight", "D"]].
# 557 cells are detected by ["PVD", ["flight", "W"]].1 cells are detected by ["PVD", ["sched_dep_time", "u"]].
#
#
# 828 cells are detected by ["PVD", ["flight", "L"]].
# 1999 cells are detected by ["PVD", ["act_dep_time", " "]].
# 1589 cells are detected by ["PVD", ["sched_dep_time", " "]].18 cells are detected by ["PVD", ["act_dep_time", "b"]].
#
# 17 cells are detected by ["PVD", ["sched_arr_time", "r"]].
# 950 cells are detected by ["PVD", ["flight", "C"]].
# 409 cells are detected by ["PVD", ["src", "p"]].
# 42 cells are detected by ["PVD", ["act_arr_time", "s"]].
# 603 cells are detected by ["PVD", ["act_arr_time", "5"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "T"]].
# 676 cells are detected by ["PVD", ["tuple_id", "3"]].
# 14275 cells are detected by ["OD", ["histogram", "0.5", "0.9"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "i"]].1333 cells are detected by ["OD", ["gaussian", "2.0"]].
#
# 16632 cells are detected by ["OD", ["histogram", "0.1", "0.9"]].14 cells are detected by ["PVD", ["act_dep_time", "C"]].
# 2728 cells are detected by ["RVD", ["sched_dep_time", "sched_arr_time"]].620 cells are detected by ["PVD", ["src", "y"]].
#
#
# 130 cells are detected by ["PVD", ["sched_arr_time", "e"]].
# 616 cells are detected by ["PVD", ["tuple_id", "4"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "O"]].
# 84 cells are detected by ["PVD", ["act_dep_time", "c"]].
# 3116 cells are detected by ["RVD", ["sched_dep_time", "tuple_id"]].
# 12412 cells are detected by ["OD", ["histogram", "0.5", "0.7"]].
# 693 cells are detected by ["OD", ["histogram", "0.5", "0.1"]].6724 cells are detected by ["OD", ["histogram", "0.3", "0.3"]].
#
# 4 cells are detected by ["PVD", ["sched_dep_time", ")"]].
# 1716 cells are detected by ["PVD", ["src", "t"]].
# 821 cells are detected by ["PVD", ["sched_dep_time", "5"]].693 cells are detected by ["OD", ["histogram", "0.7", "0.1"]].
#
# 3834 cells are detected by ["RVD", ["act_arr_time", "src"]].
# 72 cells are detected by ["PVD", ["sched_dep_time", "D"]].0 cells are detected by ["RVD", ["tuple_id", "act_dep_time"]].
#
# 4 cells are detected by ["PVD", ["act_dep_time", "+"]].
# 196 cells are detected by ["PVD", ["sched_dep_time", "6"]].964 cells are detected by ["RVD", ["act_arr_time", "flight"]].
#
# 162 cells are detected by ["PVD", ["flight", "G"]].811 cells are detected by ["PVD", ["flight", "2"]].
#
# 44 cells are detected by ["PVD", ["act_arr_time", "n"]].39 cells are detected by ["PVD", ["act_dep_time", "n"]].
#
# 18 cells are detected by ["PVD", ["act_arr_time", "v"]].
# 24 cells are detected by ["PVD", ["act_dep_time", "w"]].13 cells are detected by ["PVD", ["sched_arr_time", "N"]].3112 cells are detected by ["RVD", ["sched_arr_time", "tuple_id"]].
#
#
# 397 cells are detected by ["PVD", ["flight", "E"]].
# 4704 cells are detected by ["RVD", ["src", "sched_dep_time"]].
# 1 cells are detected by ["PVD", ["act_dep_time", "/"]].
# 527 cells are detected by ["PVD", ["sched_arr_time", "2"]].
# 539 cells are detected by ["PVD", ["src", "v"]].
# 100 cells are detected by ["PVD", ["src", "j"]].
# 30 cells are detected by ["PVD", ["act_arr_time", "w"]].1082 cells are detected by ["RVD", ["act_dep_time", "sched_dep_time"]].
#
# 174 cells are detected by ["PVD", ["sched_dep_time", "8"]].1635 cells are detected by ["KBVD", "/home/adrian/source/MA/raha/raha/tools/KATARA/knowledge-base/zipHasCity.rel.txt"].
# 331 cells are detected by ["PVD", ["sched_dep_time", "7"]].
#
# 19 cells are detected by ["PVD", ["src", "C"]].436 cells are detected by ["PVD", ["src", "c"]].
#
# 147 cells are detected by ["PVD", ["src", "k"]].
# 2378 cells are detected by ["RVD", ["sched_arr_time", "act_dep_time"]].
# 2329 cells are detected by ["PVD", ["flight", "A"]].
# 24 cells are detected by ["PVD", ["act_dep_time", "u"]].1304 cells are detected by ["RVD", ["act_arr_time", "sched_dep_time"]].
#
# 48 cells are detected by ["PVD", ["act_arr_time", "D"]].264 cells are detected by ["PVD", ["sched_arr_time", "9"]].
# 1922 cells are detected by ["OD", ["gaussian", "1.5"]].1172 cells are detected by ["RVD", ["sched_arr_time", "sched_dep_time"]].
#
#
# 1129 cells are detected by ["PVD", ["src", "a"]].
# 1525 cells are detected by ["PVD", ["sched_arr_time", "."]].
# 4752 cells are detected by ["RVD", ["flight", "act_arr_time"]].
# 3836 cells are detected by ["RVD", ["act_dep_time", "src"]].562 cells are detected by ["PVD", ["act_dep_time", "5"]].
#
# 18 cells are detected by ["PVD", ["act_arr_time", "b"]].
# 669 cells are detected by ["PVD", ["flight", "5"]].
# 4636 cells are detected by ["RVD", ["src", "act_dep_time"]].
# 805 cells are detected by ["PVD", ["act_arr_time", "a"]].
# 659 cells are detected by ["PVD", ["act_arr_time", "0"]].
# 36 cells are detected by ["PVD", ["act_arr_time", "u"]].
# 7 cells are detected by ["PVD", ["sched_arr_time", "u"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "v"]].
# 1897 cells are detected by ["PVD", ["act_dep_time", "."]].
# 4740 cells are detected by ["RVD", ["src", "sched_arr_time"]].4752 cells are detected by ["RVD", ["flight", "act_dep_time"]].
#
# 35 cells are detected by ["PVD", ["act_dep_time", "("]].13 cells are detected by ["PVD", ["sched_arr_time", "t"]].
# 279 cells are detected by ["PVD", ["flight", "J"]].
#
# 912 cells are detected by ["PVD", ["act_dep_time", "p"]].32 cells are detected by ["PVD", ["act_arr_time", "l"]].
#
# 4 cells are detected by ["PVD", ["sched_dep_time", "-"]].48 cells are detected by ["PVD", ["act_arr_time", "("]].
#
# 1101 cells are detected by ["PVD", ["src", "f"]].
# 2238 cells are detected by ["OD", ["histogram", "0.1", "0.1"]].14769 cells are detected by ["OD", ["histogram", "0.3", "0.7"]].
#
# 6 cells are detected by ["PVD", ["act_arr_time", "h"]].
# 35 cells are detected by ["PVD", ["act_dep_time", ")"]].3838 cells are detected by ["RVD", ["act_arr_time", "tuple_id"]].
# 42 cells are detected by ["PVD", ["act_arr_time", "d"]].12001 cells are detected by ["OD", ["histogram", "0.3", "0.5"]].
#
#
# 259 cells are detected by ["PVD", ["src", "d"]].821 cells are detected by ["PVD", ["src", "n"]].
#
# 1020 cells are detected by ["PVD", ["src", "g"]].
# 226 cells are detected by ["PVD", ["sched_arr_time", "6"]].9644 cells are detected by ["OD", ["histogram", "0.7", "0.5"]].
#
# 19 cells are detected by ["PVD", ["src", "O"]].1897 cells are detected by ["PVD", ["act_dep_time", "m"]].
# 668 cells are detected by ["OD", ["histogram", "0.9", "0.1"]].
# 38 cells are detected by ["PVD", ["act_dep_time", "r"]].
#
# 13 cells are detected by ["PVD", ["sched_dep_time", "A"]].32 cells are detected by ["PVD", ["act_dep_time", "o"]].
#
# 2682 cells are detected by ["RVD", ["act_arr_time", "act_dep_time"]].
# 1209 cells are detected by ["PVD", ["act_arr_time", "p"]].
# 13 cells are detected by ["PVD", ["sched_dep_time", "l"]].2836 cells are detected by ["RVD", ["sched_dep_time", "act_dep_time"]].
#
# 889 cells are detected by ["PVD", ["sched_dep_time", "0"]].
# 9566 cells are detected by ["OD", ["histogram", "0.9", "0.9"]].606 cells are detected by ["PVD", ["tuple_id", "8"]].
#
# 508 cells are detected by ["PVD", ["act_dep_time", "3"]].677 cells are detected by ["PVD", ["flight", "8"]].
# 63 cells are detected by ["PVD", ["act_dep_time", "t"]].
#
# 1910 cells are detected by ["PVD", ["act_arr_time", "."]].670 cells are detected by ["RVD", ["sched_arr_time", "flight"]].
# 1968 cells are detected by ["PVD", ["act_dep_time", ":"]].
#
# 331 cells are detected by ["PVD", ["sched_dep_time", "4"]].
# 1132 cells are detected by ["RVD", ["act_arr_time", "sched_arr_time"]].
# 64 cells are detected by ["PVD", ["act_dep_time", "i"]].1940 cells are detected by ["RVD", ["act_dep_time", "sched_arr_time"]].
#
# 3904 cells are detected by ["OD", ["gaussian", "1.0"]].
# 6724 cells are detected by ["OD", ["histogram", "0.1", "0.3"]].
# 437 cells are detected by ["PVD", ["sched_arr_time", "4"]].
# 606 cells are detected by ["PVD", ["tuple_id", "0"]].
# 2238 cells are detected by ["OD", ["histogram", "0.3", "0.1"]].
# 885 cells are detected by ["PVD", ["sched_arr_time", "5"]].
# 30 cells are detected by ["PVD", ["act_arr_time", "y"]].
# 4750 cells are detected by ["RVD", ["src", "tuple_id"]].
# 117 cells are detected by ["PVD", ["act_arr_time", "e"]].
# 74 cells are detected by ["PVD", ["act_arr_time", "t"]].
# 2144 cells are detected by ["RVD", ["sched_arr_time", "act_arr_time"]].
# 263 cells are detected by ["PVD", ["src", "m"]].
# 4367 cells are detected by ["OD", ["histogram", "0.5", "0.3"]].
# 348 cells are detected by ["PVD", ["act_arr_time", "7"]].
# 4662 cells are detected by ["RVD", ["src", "act_arr_time"]].
# 15 cells are detected by ["PVD", ["sched_dep_time", "o"]].
# 2934 cells are detected by ["OD", ["histogram", "0.9", "0.3"]].
# 14769 cells are detected by ["OD", ["histogram", "0.1", "0.7"]].
# 8 cells are detected by ["PVD", ["act_arr_time", "/"]].
# 35 cells are detected by ["PVD", ["act_arr_time", "A"]].
# 1849 cells are detected by ["OD", ["gaussian", "1.7"]].
# 1550 cells are detected by ["RVD", ["act_dep_time", "flight"]].
# 10 cells are detected by ["PVD", ["sched_dep_time", "/"]].
# 9644 cells are detected by ["OD", ["histogram", "0.5", "0.5"]].
# 37 cells are detected by ["PVD", ["act_dep_time", "l"]].
# 905 cells are detected by ["PVD", ["flight", "3"]].
# 14275 cells are detected by ["OD", ["histogram", "0.7", "0.9"]].
# 258 cells are detected by ["OD", ["gaussian", "2.7"]].
# 42 cells are detected by ["PVD", ["act_arr_time", "E"]].
# 3098 cells are detected by ["RVD", ["sched_dep_time", "src"]].
# 907 cells are detected by ["PVD", ["flight", "R"]].
# 8189 cells are detected by ["OD", ["histogram", "0.9", "0.5"]].
# 4750 cells are detected by ["RVD", ["src", "flight"]].
# 2 cells are detected by ["PVD", ["act_arr_time", "P"]].
# 0 cells are detected by ["RVD", ["tuple_id", "src"]].
# 16632 cells are detected by ["OD", ["histogram", "0.3", "0.9"]].
# 12001 cells are detected by ["OD", ["histogram", "0.1", "0.5"]].
# 0 cells are detected by ["RVD", ["tuple_id", "flight"]].
# 309 strategy profiles are collected.

# %% [markdown]
# ### 4. Generating Features
# Raha then generates a feature vector for each data cell based on the output of error detection strategies.

# %%
app_1.generate_features(d)
# Out:
# 40 Features are generated for column 0.
# 65 Features are generated for column 1.
# 62 Features are generated for column 2.
# 65 Features are generated for column 3.
# 71 Features are generated for column 4.
# 65 Features are generated for column 5.
# 86 Features are generated for column 6.

# %% [markdown]
# ### 5. Building Clusters
# Raha next builds a hierarchical clustering model for our clustering-based sampling approach.

# %%
app_1.build_clusters(d)
# Out:
# A hierarchical clustering model is built for column 0.
# A hierarchical clustering model is built for column 1.
# A hierarchical clustering model is built for column 2.
# A hierarchical clustering model is built for column 3.
# A hierarchical clustering model is built for column 4.
# A hierarchical clustering model is built for column 5.
# A hierarchical clustering model is built for column 6.

# %% [markdown]
# ### 6. Interactive Tuple Sampling and Labeling
# Raha then iteratively samples a tuple. We should label data cells of each sampled tuple.

# %%
while len(d.labeled_tuples) < app_1.LABELING_BUDGET:
    app_1.sample_tuple(d)
    if d.has_ground_truth:
        app_1.label_with_ground_truth(d)
    else:
        print("Label the dirty cells in the following sampled tuple.")
        sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
        IPython.display.display(sampled_tuple)
        for j in range(d.dataframe.shape[1]):
            cell = (d.sampled_tuple, j)
            value = d.dataframe.iloc[cell]
            correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
            user_label = 1 if value != correction else 0
            d.labeled_cells[cell] = [user_label, correction]
        d.labeled_tuples[d.sampled_tuple] = 1
# Out:
# Tuple 1676 is sampled.
# Tuple 1676 is labeled.
# Tuple 688 is sampled.
# Tuple 688 is labeled.
# Tuple 5 is sampled.
# Tuple 5 is labeled.
# Tuple 809 is sampled.
# Tuple 809 is labeled.
# Tuple 190 is sampled.
# Tuple 190 is labeled.
# Tuple 2238 is sampled.
# Tuple 2238 is labeled.
# Tuple 506 is sampled.
# Tuple 506 is labeled.
# Tuple 1859 is sampled.
# Tuple 1859 is labeled.
# Tuple 945 is sampled.
# Tuple 945 is labeled.
# Tuple 1900 is sampled.
# Tuple 1900 is labeled.
# Tuple 800 is sampled.
# Tuple 800 is labeled.
# Tuple 1249 is sampled.
# Tuple 1249 is labeled.
# Tuple 1183 is sampled.
# Tuple 1183 is labeled.
# Tuple 1453 is sampled.
# Tuple 1453 is labeled.
# Tuple 1340 is sampled.
# Tuple 1340 is labeled.
# Tuple 232 is sampled.
# Tuple 232 is labeled.
# Tuple 1043 is sampled.
# Tuple 1043 is labeled.
# Tuple 1473 is sampled.
# Tuple 1473 is labeled.
# Tuple 243 is sampled.
# Tuple 243 is labeled.
# Tuple 1775 is sampled.
# Tuple 1775 is labeled.

# %% [markdown]
# ### 7. Propagating User Labels
# Raha then propagates each user label through its cluster.

# %%
app_1.propagate_labels(d)
# Out:
# The number of labeled data cells increased from 140 to 11188.

# %% [markdown]
# ### 8. Predicting Labels of Data Cells
# Raha then trains and applies one classifier per data column to predict the label of the rest of data cells.

# %%
app_1.predict_labels(d)
# Out:
# A classifier is trained and applied on column 0.
# A classifier is trained and applied on column 1.
# A classifier is trained and applied on column 2.
# A classifier is trained and applied on column 3.
# A classifier is trained and applied on column 4.
# A classifier is trained and applied on column 5.
# A classifier is trained and applied on column 6.

# %% [markdown]
# ### 9. Storing Results
# Raha can also store the error detection results.

# %%
app_1.store_results(d)
# Out:
# The results are stored in datasets/flights/raha-baran-results-flights/error-detection/detection.dataset.

# %% [markdown]
# ### 10. Evaluating the Error Detection Task
# We can finally evaluate our error detection task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.detected_cells)[:3]
print("Raha's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))
# Out:
# Raha's performance on flights:
# Precision = 0.82
# Recall = 0.87
# F1 = 0.85

# %% [markdown]
# # Error Correction with Baran

# %% [markdown]
# ### 1. Instantiating the Correction Class
# We first instantiate the `Correction` class.

# %%
app_2 = raha.Correction()

# How many tuples would you label?
app_2.LABELING_BUDGET = 20

# Would you like to see the logs?
app_2.VERBOSE = True

# %% [markdown]
# ### 2. Initializing the Dataset Object
# We next initialize the dataset object.

# %%
d = app_2.initialize_dataset(d)
d.dataframe.head()
# Out:
#   tuple_id src           flight sched_dep_time act_dep_time sched_arr_time  \
# 0        1  aa  AA-3859-IAH-ORD      7:10 a.m.    7:16 a.m.      9:40 a.m.
# 1        2  aa  AA-1733-ORD-PHX      7:45 p.m.    7:58 p.m.     10:30 p.m.
# 2        3  aa  AA-1640-MIA-MCO      6:30 p.m.                   7:25 p.m.
# 3        4  aa   AA-518-MIA-JFK      6:40 a.m.    6:54 a.m.      9:25 a.m.
# 4        5  aa  AA-3756-ORD-SLC     12:15 p.m.   12:41 p.m.      2:45 p.m.
#
#   act_arr_time
# 0    9:32 a.m.
# 1
# 2
# 3    9:28 a.m.
# 4    2:50 p.m.

# %% [markdown]
# ### 3. Initializing the Error Corrector Models
# Baran initializes the error corrector models.

# %%
app_2.initialize_models(d)
# Out:
# The error corrector models are initialized.

# %% [markdown]
# ### 4. Interactive Tuple Sampling, Labeling, Model updating, Feature Generation, and Correction Prediction
# Baran then iteratively samples a tuple. We should label data cells of each sampled tuple. It then udpates the models accordingly and generates a feature vector for each pair of a data error and a correction candidate. Finally, it trains and applies a classifier to each data column to predict the final correction of each data error. Since we already labeled tuples for Raha, we use the same labeled tuples and do not label new tuples here.

# %%
# while len(d.labeled_tuples) < app_2.LABELING_BUDGET:
#     app_2.sample_tuple(d)
#     if d.has_ground_truth:
#         app_2.label_with_ground_truth(d)
#     else:
#         print("Label the dirty cells in the following sampled tuple.")
#         sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
#         IPython.display.display(sampled_tuple)
#         for j in range(d.dataframe.shape[1]):
#             cell = (d.sampled_tuple, j)
#             value = d.dataframe.iloc[cell]
#             correction = input("What is the correction for value '{}'? Type in the same value if it is not erronous.\n".format(value))
#             user_label = 1 if value != correction else 0
#             d.labeled_cells[cell] = [user_label, correction]
#         d.labeled_tuples[d.sampled_tuple] = 1
#     app_2.update_models(d)
#     app_2.generate_features(d)
#     app_2.predict_corrections(d)

for si in d.labeled_tuples:
    d.sampled_tuple = si
    app_2.update_models(d)
    app_2.generate_features(d)
    app_2.predict_corrections(d)
# Out:
# The error corrector models are updated with new labeled tuple 1676.
# 490353 pairs of (a data error, a potential correction) are featurized.
# 50% (2619 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 688.
# 496333 pairs of (a data error, a potential correction) are featurized.
# 50% (2634 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 5.
# 501895 pairs of (a data error, a potential correction) are featurized.
# 51% (2685 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 809.
# 508650 pairs of (a data error, a potential correction) are featurized.
# 55% (2867 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 190.
# 521136 pairs of (a data error, a potential correction) are featurized.
# 56% (2907 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2238.
# 531573 pairs of (a data error, a potential correction) are featurized.
# 56% (2916 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 506.
# 537371 pairs of (a data error, a potential correction) are featurized.
# 56% (2943 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1859.
# 537371 pairs of (a data error, a potential correction) are featurized.
# 56% (2943 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 945.
# 544236 pairs of (a data error, a potential correction) are featurized.
# 57% (2954 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1900.
# 544236 pairs of (a data error, a potential correction) are featurized.
# 57% (2954 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 800.
# 549476 pairs of (a data error, a potential correction) are featurized.
# 57% (2992 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1249.
# 561885 pairs of (a data error, a potential correction) are featurized.
# 58% (3045 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1183.
# 565280 pairs of (a data error, a potential correction) are featurized.
# 59% (3060 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1453.
# 565280 pairs of (a data error, a potential correction) are featurized.
# 59% (3073 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1340.
# 567175 pairs of (a data error, a potential correction) are featurized.
# 59% (3100 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 232.
# 567686 pairs of (a data error, a potential correction) are featurized.
# 59% (3100 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1043.
# 570599 pairs of (a data error, a potential correction) are featurized.
# 59% (3100 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1473.
# 572012 pairs of (a data error, a potential correction) are featurized.
# 60% (3123 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 243.
# 572109 pairs of (a data error, a potential correction) are featurized.
# 60% (3123 / 5223) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1775.
# 575179 pairs of (a data error, a potential correction) are featurized.
# 60% (3123 / 5223) of data errors are corrected.

# %% [markdown]
# ### 5. Storing Results
# Baran can also store the error correction results.

# %%
app_2.store_results(d)
# Out:
# The results are stored in datasets/flights/raha-baran-results-flights/error-correction/correction.dataset.

# %% [markdown]
# ### 6. Evaluating the Error Correction Task
# We can finally evaluate our error correction task.

# %%
p, r, f = d.get_data_cleaning_evaluation(d.corrected_cells)[-3:]
print("Baran's performance on {}:\nPrecision = {:.2f}\nRecall = {:.2f}\nF1 = {:.2f}".format(d.name, p, r, f))
# Out:
# Baran's performance on flights:
# Precision = 0.80
# Recall = 0.51
# F1 = 0.62

# %%
d?
# Out:
# Type:           Dataset
# String form:    <raha.dataset.Dataset object at 0x7fd27edbab50>
# File:           ~/source/MA/raha/raha/dataset.py
# Docstring:      The dataset class.
# Init docstring: The constructor creates a dataset.

# %%
d.corrected_cells
# Out:
# {(506, 3): '7:35 a.m.',
#  (688, 3): '1:29 p.m.',
#  (809, 3): '7:15 a.m.',
#  (1249, 3): '6:00 a.m.',
#  (1340, 3): '8:15 a.m.',
#  (1775, 3): '8:15 a.m.',
#  (2238, 3): '9:05 a.m.',
#  (50, 3): '7:10 a.m.',
#  (52, 3): '6:40 a.m.',
#  (53, 3): '8:00 a.m.',
#  (54, 3): '8:41 a.m.',
#  (55, 3): '7:45 p.m.',
#  (56, 3): '3:27 p.m.',
#  (58, 3): '11:25 a.m.',
#  (59, 3): '10:39 a.m.',
#  (60, 3): '11:25 p.m.',
#  (61, 3): '6:00 a.m.',
#  (63, 3): '4:00 p.m.',
#  (66, 3): '9:05 a.m.',
#  (67, 3): '8:15 a.m.',
#  (68, 3): '7:00 a.m.',
#  (69, 3): '4:15 p.m.',
#  (70, 3): '10:45 a.m.',
#  (73, 3): '2:55 p.m.',
#  (74, 3): '11:50 a.m.',
#  (76, 3): '6:00 a.m.',
#  (77, 3): '11:05 a.m.',
#  (80, 3): '10:15 a.m.',
#  (81, 3): '1:00 p.m.',
#  (82, 3): '7:53 a.m.',
#  (83, 3): '12:30 p.m.',
#  (84, 3): '11:45 a.m.',
#  (85, 3): '2:30 p.m.',
#  (86, 3): '12:00 p.m.',
#  (89, 3): '10:40 a.m.',
#  (90, 3): '12:57 p.m.',
#  (92, 3): '7:15 a.m.',
#  (93, 3): '6:30 p.m.',
#  (94, 3): '6:45 p.m.',
#  (95, 3): '12:00 p.m.',
#  (97, 3): '1:55 p.m.',
#  (99, 3): '6:00 a.m.',
#  (100, 3): '7:10 a.m.',
#  (101, 3): '4:55 p.m.',
#  (102, 3): '7:25 a.m.',
#  (103, 3): '3:50 p.m.',
#  (104, 3): '4:16 p.m.',
#  (105, 3): '8:00 p.m.',
#  (107, 3): '7:05 a.m.',
#  (108, 3): '10:40 a.m.',
#  (109, 3): '1:33 p.m.',
#  (110, 3): '12:15 p.m.',
#  (112, 3): '11:55 p.m.',
#  (113, 3): '4:25 p.m.',
#  (114, 3): '9:00 p.m.',
#  (115, 3): '8:25 p.m.',
#  (116, 3): '6:59 a.m.',
#  (117, 3): '8:35 a.m.',
#  (118, 3): '8:29 a.m.',
#  (119, 3): '1:30 p.m.',
#  (121, 3): '7:35 a.m.',
#  (123, 3): '5:30 p.m.',
#  (124, 3): '1:45 p.m.',
#  (125, 3): '11:15 a.m.',
#  (126, 3): '8:20 p.m.',
#  (127, 3): '2:55 p.m.',
#  (130, 3): '2:35 p.m.',
#  (131, 3): '2:55 p.m.',
#  (132, 3): '7:15 a.m.',
#  (133, 3): '12:10 p.m.',
#  (134, 3): '7:55 a.m.',
#  (135, 3): '9:05 a.m.',
#  (136, 3): '1:05 p.m.',
#  (137, 3): '8:35 a.m.',
#  (138, 3): '3:05 p.m.',
#  (139, 3): '7:30 a.m.',
#  (140, 3): '4:00 p.m.',
#  (141, 3): '11:35 a.m.',
#  (143, 3): '11:55 a.m.',
#  (144, 3): '10:40 a.m.',
#  (145, 3): '6:45 a.m.',
#  (147, 3): '6:00 a.m.',
#  (148, 3): '7:10 a.m.',
#  (149, 3): '7:10 a.m.',
#  (151, 3): '7:00 p.m.',
#  (154, 3): '8:41 a.m.',
#  (158, 3): '11:25 a.m.',
#  (159, 3): '10:39 a.m.',
#  (161, 3): '6:00 a.m.',
#  (162, 3): '12:30 a.m.',
#  (164, 3): '7:35 a.m.',
#  (165, 3): '9:45 a.m.',
#  (167, 3): '8:15 a.m.',
#  (170, 3): '10:45 a.m.',
#  (171, 3): '2:30 p.m.',
#  (172, 3): '8:05 a.m.',
#  (173, 3): '2:55 p.m.',
#  (175, 3): '11:40 a.m.',
#  (178, 3): '6:00 a.m.',
#  (179, 3): '8:40 a.m.',
#  (182, 3): '7:53 a.m.',
#  (183, 3): '12:30 p.m.',
#  (184, 3): '11:45 a.m.',
#  (187, 3): '5:25 p.m.',
#  (188, 3): '7:10 p.m.',
#  (191, 3): '3:35 p.m.',
#  (196, 3): '1:55 p.m.',
#  (200, 3): '4:55 p.m.',
#  (202, 3): '4:16 p.m.',
#  (204, 3): '10:25 a.m.',
#  (205, 3): '7:05 a.m.',
#  (209, 3): '1:29 p.m.',
#  (216, 3): '8:29 a.m.',
#  (218, 3): '2:53 p.m.',
#  (219, 3): '7:35 a.m.',
#  (222, 3): '1:45 p.m.',
#  (223, 3): '11:15 a.m.',
#  (224, 3): '8:20 p.m.',
#  (225, 3): '2:55 p.m.',
#  (226, 3): '2:30 p.m.',
#  (227, 3): '8:55 a.m.',
#  (233, 3): '9:05 a.m.',
#  (235, 3): '8:35 a.m.',
#  (238, 3): '11:25 a.m.',
#  (242, 3): '2:55 p.m.',
#  (337, 3): '7:10 a.m.',
#  (339, 3): '6:40 a.m.',
#  (340, 3): '8:00 a.m.',
#  (341, 3): '8:41 a.m.',
#  (342, 3): '7:45 p.m.',
#  (343, 3): '3:27 p.m.',
#  (345, 3): '11:25 a.m.',
#  (346, 3): '10:39 a.m.',
#  (347, 3): '11:25 p.m.',
#  (348, 3): '6:00 a.m.',
#  (350, 3): '4:00 p.m.',
#  (353, 3): '9:05 a.m.',
#  (354, 3): '8:15 a.m.',
#  (355, 3): '7:00 a.m.',
#  (356, 3): '4:15 p.m.',
#  (357, 3): '10:45 a.m.',
#  (360, 3): '2:55 p.m.',
#  (361, 3): '11:50 a.m.',
#  (363, 3): '6:00 a.m.',
#  (364, 3): '11:05 a.m.',
#  (367, 3): '10:15 a.m.',
#  (368, 3): '1:00 p.m.',
#  (369, 3): '7:53 a.m.',
#  (370, 3): '12:30 p.m.',
#  (371, 3): '11:45 a.m.',
#  (372, 3): '2:30 p.m.',
#  (373, 3): '12:00 p.m.',
#  (376, 3): '10:40 a.m.',
#  (377, 3): '12:57 p.m.',
#  (379, 3): '7:15 a.m.',
#  (380, 3): '6:30 p.m.',
#  (381, 3): '6:45 p.m.',
#  (382, 3): '12:00 p.m.',
#  (384, 3): '1:55 p.m.',
#  (386, 3): '6:00 a.m.',
#  (387, 3): '7:10 a.m.',
#  (388, 3): '4:55 p.m.',
#  (389, 3): '7:25 a.m.',
#  (390, 3): '3:50 p.m.',
#  (391, 3): '4:16 p.m.',
#  (392, 3): '8:00 p.m.',
#  (394, 3): '7:05 a.m.',
#  (395, 3): '10:40 a.m.',
#  (396, 3): '1:33 p.m.',
#  (397, 3): '12:15 p.m.',
#  (399, 3): '11:55 p.m.',
#  (400, 3): '4:25 p.m.',
#  (401, 3): '9:00 p.m.',
#  (402, 3): '8:25 p.m.',
#  (403, 3): '6:59 a.m.',
#  (404, 3): '8:35 a.m.',
#  (405, 3): '8:29 a.m.',
#  (406, 3): '1:30 p.m.',
#  (408, 3): '7:35 a.m.',
#  (410, 3): '5:30 p.m.',
#  (411, 3): '1:45 p.m.',
#  (412, 3): '11:15 a.m.',
#  (413, 3): '8:20 p.m.',
#  (414, 3): '2:55 p.m.',
#  (417, 3): '2:35 p.m.',
#  (418, 3): '2:55 p.m.',
#  (419, 3): '7:15 a.m.',
#  (420, 3): '12:10 p.m.',
#  (421, 3): '7:55 a.m.',
#  (422, 3): '9:05 a.m.',
#  (423, 3): '1:05 p.m.',
#  (424, 3): '8:35 a.m.',
#  (425, 3): '3:05 p.m.',
#  (426, 3): '7:30 a.m.',
#  (427, 3): '4:00 p.m.',
#  (428, 3): '11:35 a.m.',
#  (430, 3): '11:55 a.m.',
#  (431, 3): '10:40 a.m.',
#  (432, 3): '6:45 a.m.',
#  (434, 3): '6:00 a.m.',
#  (435, 3): '7:10 a.m.',
#  (436, 3): '7:10 a.m.',
#  (438, 3): '7:00 p.m.',
#  (441, 3): '8:41 a.m.',
#  (445, 3): '11:25 a.m.',
#  (446, 3): '10:39 a.m.',
#  (448, 3): '6:00 a.m.',
#  (449, 3): '12:30 a.m.',
#  (451, 3): '7:35 a.m.',
#  (452, 3): '9:45 a.m.',
#  (454, 3): '8:15 a.m.',
#  (457, 3): '10:45 a.m.',
#  (458, 3): '2:30 p.m.',
#  (459, 3): '8:05 a.m.',
#  (460, 3): '2:55 p.m.',
#  (462, 3): '11:40 a.m.',
#  (465, 3): '6:00 a.m.',
#  (466, 3): '8:40 a.m.',
#  (469, 3): '7:53 a.m.',
#  (470, 3): '12:30 p.m.',
#  (471, 3): '11:45 a.m.',
#  (474, 3): '5:25 p.m.',
#  (475, 3): '7:10 p.m.',
#  (477, 3): '12:57 p.m.',
#  (478, 3): '3:35 p.m.',
#  (483, 3): '1:55 p.m.',
#  (487, 3): '4:55 p.m.',
#  (489, 3): '4:16 p.m.',
#  (491, 3): '10:25 a.m.',
#  (492, 3): '7:05 a.m.',
#  (496, 3): '1:29 p.m.',
#  (503, 3): '8:29 a.m.',
#  (505, 3): '2:53 p.m.',
#  (509, 3): '1:45 p.m.',
#  (510, 3): '11:15 a.m.',
#  (511, 3): '8:20 p.m.',
#  (512, 3): '2:55 p.m.',
#  (513, 3): '2:30 p.m.',
#  (514, 3): '8:55 a.m.',
#  (520, 3): '9:05 a.m.',
#  (522, 3): '8:35 a.m.',
#  (525, 3): '11:25 a.m.',
#  (529, 3): '2:55 p.m.',
#  (630, 3): '7:00 p.m.',
#  (633, 3): '8:41 a.m.',
#  (637, 3): '11:25 a.m.',
#  (638, 3): '10:39 a.m.',
#  (640, 3): '6:00 a.m.',
#  (641, 3): '12:30 a.m.',
#  (643, 3): '7:35 a.m.',
#  (644, 3): '9:45 a.m.',
#  (646, 3): '8:15 a.m.',
#  (649, 3): '10:45 a.m.',
#  (650, 3): '2:30 p.m.',
#  (651, 3): '8:05 a.m.',
#  (652, 3): '2:55 p.m.',
#  (654, 3): '11:40 a.m.',
#  (657, 3): '6:00 a.m.',
#  (658, 3): '8:40 a.m.',
#  (661, 3): '7:53 a.m.',
#  (662, 3): '12:30 p.m.',
#  (663, 3): '11:45 a.m.',
#  (666, 3): '5:25 p.m.',
#  (667, 3): '7:10 p.m.',
#  (669, 3): '12:57 p.m.',
#  (670, 3): '3:35 p.m.',
#  (675, 3): '1:55 p.m.',
#  (679, 3): '4:55 p.m.',
#  (681, 3): '4:16 p.m.',
#  (683, 3): '10:25 a.m.',
#  (684, 3): '7:05 a.m.',
#  (695, 3): '8:29 a.m.',
#  (697, 3): '2:53 p.m.',
#  (698, 3): '7:35 a.m.',
#  (701, 3): '1:45 p.m.',
#  (702, 3): '11:15 a.m.',
#  (703, 3): '8:20 p.m.',
#  (704, 3): '2:55 p.m.',
#  (705, 3): '2:30 p.m.',
#  (706, 3): '8:55 a.m.',
#  (712, 3): '9:05 a.m.',
#  (714, 3): '8:35 a.m.',
#  (717, 3): '11:25 a.m.',
#  (721, 3): '2:55 p.m.',
#  (729, 3): '7:10 a.m.',
#  (730, 3): '7:45 p.m.',
#  (731, 3): '7:00 p.m.',
#  (732, 3): '8:00 a.m.',
#  (733, 3): '8:41 a.m.',
#  (735, 3): '11:25 a.m.',
#  (736, 3): '10:39 a.m.',
#  (738, 3): '6:00 a.m.',
#  (739, 3): '12:30 a.m.',
#  (740, 3): '12:15 p.m.',
#  (741, 3): '7:00 a.m.',
#  (742, 3): '4:15 p.m.',
#  (743, 3): '9:05 a.m.',
#  (744, 3): '11:50 a.m.',
#  (745, 3): '11:40 a.m.',
#  (746, 3): '6:00 a.m.',
#  (747, 3): '7:55 a.m.',
#  (748, 3): '10:15 a.m.',
#  (749, 3): '7:30 a.m.',
#  (750, 3): '1:00 p.m.',
#  (751, 3): '12:30 p.m.',
#  (752, 3): '11:45 a.m.',
#  (753, 3): '2:30 p.m.',
#  (754, 3): '11:35 a.m.',
#  (755, 3): '10:40 a.m.',
#  (757, 3): '3:35 p.m.',
#  (758, 3): '7:15 a.m.',
#  (759, 3): '6:45 p.m.',
#  (760, 3): '12:00 p.m.',
#  (761, 3): '9:15 a.m.',
#  (762, 3): '6:00 a.m.',
#  (763, 3): '7:10 a.m.',
#  (764, 3): '4:55 p.m.',
#  (765, 3): '7:25 a.m.',
#  (766, 3): '4:16 p.m.',
#  (767, 3): '8:00 p.m.',
#  (768, 3): '10:45 a.m.',
#  (769, 3): '1:33 p.m.',
#  (770, 3): '1:29 p.m.',
#  (774, 3): '6:59 a.m.',
#  (775, 3): '8:35 a.m.',
#  (776, 3): '8:29 a.m.',
#  (778, 3): '11:08 p.m.',
#  (780, 3): '8:05 a.m.',
#  (781, 3): '2:35 p.m.',
#  (782, 3): '7:15 a.m.',
#  (784, 3): '7:35 a.m.',
#  (785, 3): '12:10 p.m.',
#  (786, 3): '1:05 p.m.',
#  (787, 3): '7:10 a.m.',
#  (788, 3): '10:40 a.m.',
#  (789, 3): '6:45 a.m.',
#  (790, 3): '6:00 a.m.',
#  (791, 3): '7:10 a.m.',
#  (792, 3): '10:40 a.m.',
#  (793, 3): '6:59 a.m.',
#  (794, 3): '4:15 p.m.',
#  (795, 3): '6:00 a.m.',
#  (796, 3): '7:25 a.m.',
#  (797, 3): '12:30 p.m.',
#  (803, 3): '7:00 p.m.',
#  (804, 3): '2:55 p.m.',
#  (805, 3): '6:30 p.m.',
#  (806, 3): '6:45 a.m.',
#  (807, 3): '11:25 p.m.',
#  (808, 3): '8:00 p.m.',
#  (810, 3): '9:15 a.m.',
#  (812, 3): '7:00 p.m.',
#  (815, 3): '8:41 a.m.',
#  (819, 3): '11:25 a.m.',
#  (820, 3): '10:39 a.m.',
#  (822, 3): '6:00 a.m.',
#  (823, 3): '12:30 a.m.',
#  (825, 3): '7:35 a.m.',
#  (826, 3): '9:45 a.m.',
#  (828, 3): '8:15 a.m.',
#  (831, 3): '10:45 a.m.',
#  (832, 3): '2:30 p.m.',
#  (833, 3): '8:05 a.m.',
#  (834, 3): '2:55 p.m.',
#  (836, 3): '11:40 a.m.',
#  (839, 3): '6:00 a.m.',
#  (840, 3): '8:40 a.m.',
#  (843, 3): '7:53 a.m.',
#  (844, 3): '12:30 p.m.',
#  (845, 3): '11:45 a.m.',
#  (848, 3): '5:25 p.m.',
#  (849, 3): '7:10 p.m.',
#  (851, 3): '12:57 p.m.',
#  (852, 3): '3:35 p.m.',
#  (857, 3): '1:55 p.m.',
#  (861, 3): '4:55 p.m.',
#  (863, 3): '4:16 p.m.',
#  (865, 3): '10:25 a.m.',
#  (866, 3): '7:05 a.m.',
#  (867, 3): '10:40 a.m.',
#  (870, 3): '1:29 p.m.',
#  (877, 3): '8:29 a.m.',
#  (879, 3): '2:53 p.m.',
#  (880, 3): '7:35 a.m.',
#  (883, 3): '1:45 p.m.',
#  (884, 3): '11:15 a.m.',
#  (885, 3): '8:20 p.m.',
#  (886, 3): '2:55 p.m.',
#  (887, 3): '2:30 p.m.',
#  (888, 3): '8:55 a.m.',
#  (894, 3): '9:05 a.m.',
#  (896, 3): '8:35 a.m.',
#  (899, 3): '11:25 a.m.',
#  (903, 3): '2:55 p.m.',
#  (914, 3): '11:45 a.m.',
#  (917, 3): '7:35 a.m.',
#  (925, 3): '12:30 p.m.',
#  (926, 3): '2:55 p.m.',
#  (935, 3): '4:16 p.m.',
#  (938, 3): '7:05 a.m.',
#  (950, 3): '11:15 a.m.',
#  (952, 3): '8:55 a.m.',
#  (953, 3): '8:05 a.m.',
#  (960, 3): '7:53 a.m.',
#  (964, 3): '8:40 a.m.',
#  (991, 3): '8:00 a.m.',
#  (992, 3): '8:41 a.m.',
#  (999, 3): '6:00 a.m.',
#  (1003, 3): '8:15 a.m.',
#  (1026, 3): '1:55 p.m.',
#  (1034, 3): '1:33 p.m.',
#  (1041, 3): '2:30 p.m.',
#  (1042, 3): '8:29 a.m.',
#  (1045, 3): '7:35 a.m.',
#  (1046, 3): '1:45 p.m.',
#  (1058, 3): '7:53 a.m.',
#  (1071, 3): '7:00 p.m.',
#  (1074, 3): '8:41 a.m.',
#  (1078, 3): '11:25 a.m.',
#  (1079, 3): '10:39 a.m.',
#  (1081, 3): '6:00 a.m.',
#  (1082, 3): '12:30 a.m.',
#  (1084, 3): '7:35 a.m.',
#  (1085, 3): '9:45 a.m.',
#  (1087, 3): '8:15 a.m.',
#  (1090, 3): '10:45 a.m.',
#  (1091, 3): '2:30 p.m.',
#  (1092, 3): '8:05 a.m.',
#  (1093, 3): '2:55 p.m.',
#  (1095, 3): '11:40 a.m.',
#  (1098, 3): '6:00 a.m.',
#  (1099, 3): '8:40 a.m.',
#  (1102, 3): '7:53 a.m.',
#  (1103, 3): '12:30 p.m.',
#  (1104, 3): '11:45 a.m.',
#  (1107, 3): '5:25 p.m.',
#  (1108, 3): '7:10 p.m.',
#  (1110, 3): '12:57 p.m.',
#  (1111, 3): '3:35 p.m.',
#  (1116, 3): '1:55 p.m.',
#  (1120, 3): '4:55 p.m.',
#  (1122, 3): '4:16 p.m.',
#  (1124, 3): '10:25 a.m.',
#  (1125, 3): '7:05 a.m.',
#  (1129, 3): '1:29 p.m.',
#  (1136, 3): '8:29 a.m.',
#  (1138, 3): '2:53 p.m.',
#  (1139, 3): '7:35 a.m.',
#  (1142, 3): '1:45 p.m.',
#  (1143, 3): '11:15 a.m.',
#  (1144, 3): '8:20 p.m.',
#  (1145, 3): '2:55 p.m.',
#  (1146, 3): '2:30 p.m.',
#  (1147, 3): '8:55 a.m.',
#  (1153, 3): '9:05 a.m.',
#  (1155, 3): '8:35 a.m.',
#  (1158, 3): '11:25 a.m.',
#  (1162, 3): '2:55 p.m.',
#  (1172, 3): '7:00 p.m.',
#  (1175, 3): '6:00 a.m.',
#  (1176, 3): '8:15 a.m.',
#  (1179, 3): '5:25 p.m.',
#  (1186, 3): '12:30 p.m.',
#  (1193, 3): '1:55 p.m.',
#  (1202, 3): '2:53 p.m.',
#  (1203, 3): '7:35 a.m.',
#  (1206, 3): '11:15 a.m.',
#  (1207, 3): '2:55 p.m.',
#  (1208, 3): '8:55 a.m.',
#  (1223, 3): '7:10 a.m.',
#  (1225, 3): '6:40 a.m.',
#  (1226, 3): '8:00 a.m.',
#  (1227, 3): '8:41 a.m.',
#  (1228, 3): '7:45 p.m.',
#  (1229, 3): '3:27 p.m.',
#  (1231, 3): '11:25 a.m.',
#  (1232, 3): '10:39 a.m.',
#  (1233, 3): '11:25 p.m.',
#  (1234, 3): '6:00 a.m.',
#  (1236, 3): '4:00 p.m.',
#  (1239, 3): '9:05 a.m.',
#  (1240, 3): '8:15 a.m.',
#  (1241, 3): '7:00 a.m.',
#  (1242, 3): '4:15 p.m.',
#  (1243, 3): '10:45 a.m.',
#  (1246, 3): '2:55 p.m.',
#  (1247, 3): '11:50 a.m.',
#  (1250, 3): '11:05 a.m.',
#  (1253, 3): '10:15 a.m.',
#  (1254, 3): '1:00 p.m.',
#  (1255, 3): '7:53 a.m.',
#  (1256, 3): '12:30 p.m.',
#  (1257, 3): '11:45 a.m.',
#  (1258, 3): '2:30 p.m.',
#  (1259, 3): '12:00 p.m.',
#  (1262, 3): '10:40 a.m.',
#  (1263, 3): '12:57 p.m.',
#  (1265, 3): '7:15 a.m.',
#  (1266, 3): '6:30 p.m.',
#  (1267, 3): '6:45 p.m.',
#  (1268, 3): '12:00 p.m.',
#  (1270, 3): '1:55 p.m.',
#  (1272, 3): '6:00 a.m.',
#  (1273, 3): '7:10 a.m.',
#  (1274, 3): '4:55 p.m.',
#  (1275, 3): '7:25 a.m.',
#  (1276, 3): '3:50 p.m.',
#  (1277, 3): '4:16 p.m.',
#  (1278, 3): '8:00 p.m.',
#  (1280, 3): '7:05 a.m.',
#  (1281, 3): '10:40 a.m.',
#  (1282, 3): '1:33 p.m.',
#  (1283, 3): '12:15 p.m.',
#  (1285, 3): '11:55 p.m.',
#  (1286, 3): '4:25 p.m.',
#  (1287, 3): '9:00 p.m.',
#  (1288, 3): '8:25 p.m.',
#  (1289, 3): '6:59 a.m.',
#  (1290, 3): '8:35 a.m.',
#  (1291, 3): '8:29 a.m.',
#  (1292, 3): '1:30 p.m.',
#  (1294, 3): '7:35 a.m.',
#  (1296, 3): '5:30 p.m.',
#  (1297, 3): '1:45 p.m.',
#  (1298, 3): '11:15 a.m.',
#  (1299, 3): '8:20 p.m.',
#  (1300, 3): '2:55 p.m.',
#  (1303, 3): '2:35 p.m.',
#  (1304, 3): '2:55 p.m.',
#  (1305, 3): '7:15 a.m.',
#  (1306, 3): '12:10 p.m.',
#  (1307, 3): '7:55 a.m.',
#  (1308, 3): '9:05 a.m.',
#  (1309, 3): '1:05 p.m.',
#  (1310, 3): '8:35 a.m.',
#  (1311, 3): '3:05 p.m.',
#  (1312, 3): '7:30 a.m.',
#  (1313, 3): '4:00 p.m.',
#  (1314, 3): '11:35 a.m.',
#  (1316, 3): '11:55 a.m.',
#  (1317, 3): '10:40 a.m.',
#  (1318, 3): '6:45 a.m.',
#  (1320, 3): '6:00 a.m.',
#  (1321, 3): '7:10 a.m.',
#  (1322, 3): '7:10 a.m.',
#  (1323, 3): '7:10 a.m.',
#  (1325, 3): '6:40 a.m.',
#  (1326, 3): '8:00 a.m.',
#  (1327, 3): '8:41 a.m.',
#  (1331, 3): '11:25 a.m.',
#  (1332, 3): '10:39 a.m.',
#  (1334, 3): '6:00 a.m.',
#  (1335, 3): '12:30 a.m.',
#  (1337, 3): '7:35 a.m.',
#  (1338, 3): '9:45 a.m.',
#  (1339, 3): '9:05 a.m.',
#  (1341, 3): '7:00 a.m.',
#  (1343, 3): '10:45 a.m.',
#  (1345, 3): '8:05 a.m.',
#  (1347, 3): '11:50 a.m.',
#  (1348, 3): '11:40 a.m.',
#  (1349, 3): '6:00 a.m.',
#  (1350, 3): '11:05 a.m.',
#  (1351, 3): '6:00 a.m.',
#  (1352, 3): '8:40 a.m.',
#  (1353, 3): '10:15 a.m.',
#  (1355, 3): '7:53 a.m.',
#  (1357, 3): '11:45 a.m.',
#  (1362, 3): '10:40 a.m.',
#  (1365, 3): '7:15 a.m.',
#  (1370, 3): '9:15 a.m.',
#  (1371, 3): '6:00 a.m.',
#  (1372, 3): '7:10 a.m.',
#  (1377, 3): '10:25 a.m.',
#  (1378, 3): '7:05 a.m.',
#  (1379, 3): '10:40 a.m.',
#  (1387, 3): '6:59 a.m.',
#  (1388, 3): '8:35 a.m.',
#  (1391, 3): '7:35 a.m.',
#  (1395, 3): '11:15 a.m.',
#  (1399, 3): '8:55 a.m.',
#  (1402, 3): '7:15 a.m.',
#  (1404, 3): '7:55 a.m.',
#  (1405, 3): '9:05 a.m.',
#  (1407, 3): '8:35 a.m.',
#  (1409, 3): '7:30 a.m.',
#  (1410, 3): '11:25 a.m.',
#  (1412, 3): '11:35 a.m.',
#  (1413, 3): '7:25 a.m.',
#  (1415, 3): '11:55 a.m.',
#  (1416, 3): '10:40 a.m.',
#  (1417, 3): '6:45 a.m.',
#  (1419, 3): '6:00 a.m.',
#  (1420, 3): '7:10 a.m.',
#  (1421, 3): '7:10 a.m.',
#  (1422, 3): '11:50 a.m.',
#  (1423, 3): '8:29 a.m.',
#  (1425, 3): '1:33 p.m.',
#  (1481, 3): '8:00 a.m.',
#  (1482, 3): '3:05 p.m.',
#  (1483, 3): '8:35 a.m.',
#  (1484, 3): '7:10 a.m.',
#  (1485, 3): '2:30 p.m.',
#  (1486, 3): '6:00 a.m.',
#  (1487, 3): '7:10 a.m.',
#  (1489, 3): '6:40 a.m.',
#  (1490, 3): '8:00 a.m.',
#  (1491, 3): '8:41 a.m.',
#  (1492, 3): '7:45 p.m.',
#  (1493, 3): '3:27 p.m.',
#  (1495, 3): '11:25 a.m.',
#  (1496, 3): '10:39 a.m.',
#  (1497, 3): '11:25 p.m.',
#  (1498, 3): '6:00 a.m.',
#  (1500, 3): '4:00 p.m.',
#  (1503, 3): '9:05 a.m.',
#  (1504, 3): '8:15 a.m.',
#  (1505, 3): '7:00 a.m.',
#  (1506, 3): '4:15 p.m.',
#  (1507, 3): '10:45 a.m.',
#  (1510, 3): '2:55 p.m.',
#  (1511, 3): '11:50 a.m.',
#  (1513, 3): '6:00 a.m.',
#  (1514, 3): '11:05 a.m.',
#  (1517, 3): '10:15 a.m.',
#  (1518, 3): '1:00 p.m.',
#  (1519, 3): '7:53 a.m.',
#  (1520, 3): '12:30 p.m.',
#  (1521, 3): '11:45 a.m.',
#  (1522, 3): '2:30 p.m.',
#  (1523, 3): '12:00 p.m.',
#  (1526, 3): '10:40 a.m.',
#  (1527, 3): '12:57 p.m.',
#  (1529, 3): '7:15 a.m.',
#  (1530, 3): '6:30 p.m.',
#  (1531, 3): '6:45 p.m.',
#  (1532, 3): '12:00 p.m.',
#  (1534, 3): '1:55 p.m.',
#  (1536, 3): '6:00 a.m.',
#  (1537, 3): '7:10 a.m.',
#  (1538, 3): '4:55 p.m.',
#  (1539, 3): '7:25 a.m.',
#  (1540, 3): '3:50 p.m.',
#  (1541, 3): '4:16 p.m.',
#  (1542, 3): '8:00 p.m.',
#  (1544, 3): '7:05 a.m.',
#  (1545, 3): '10:40 a.m.',
#  (1546, 3): '1:33 p.m.',
#  (1547, 3): '12:15 p.m.',
#  (1549, 3): '11:55 p.m.',
#  (1550, 3): '4:25 p.m.',
#  (1551, 3): '9:00 p.m.',
#  (1552, 3): '8:25 p.m.',
#  (1553, 3): '6:59 a.m.',
#  (1554, 3): '8:35 a.m.',
#  (1555, 3): '8:29 a.m.',
#  (1556, 3): '1:30 p.m.',
#  (1558, 3): '7:35 a.m.',
#  (1560, 3): '5:30 p.m.',
#  (1561, 3): '1:45 p.m.',
#  (1562, 3): '11:15 a.m.',
#  (1563, 3): '8:20 p.m.',
#  (1564, 3): '2:55 p.m.',
#  (1567, 3): '2:35 p.m.',
#  (1568, 3): '2:55 p.m.',
#  (1569, 3): '7:15 a.m.',
#  (1570, 3): '12:10 p.m.',
#  (1571, 3): '7:55 a.m.',
#  (1572, 3): '9:05 a.m.',
#  (1573, 3): '1:05 p.m.',
#  (1574, 3): '8:35 a.m.',
#  (1575, 3): '3:05 p.m.',
#  (1576, 3): '7:30 a.m.',
#  (1577, 3): '4:00 p.m.',
#  (1578, 3): '11:35 a.m.',
#  (1580, 3): '11:55 a.m.',
#  (1581, 3): '10:40 a.m.',
#  (1582, 3): '6:45 a.m.',
#  (1584, 3): '6:00 a.m.',
#  (1585, 3): '7:10 a.m.',
#  (1586, 3): '7:10 a.m.',
#  (1589, 3): '8:41 a.m.',
#  (1592, 3): '10:39 a.m.',
#  (1594, 3): '12:30 a.m.',
#  (1596, 3): '9:45 a.m.',
#  (1597, 3): '7:00 a.m.',
#  (1599, 3): '11:40 a.m.',
#  (1600, 3): '6:00 a.m.',
#  (1601, 3): '11:05 a.m.',
#  (1603, 3): '7:30 a.m.',
#  (1606, 3): '11:45 a.m.',
#  (1610, 3): '6:00 a.m.',
#  (1611, 3): '7:10 a.m.',
#  (1613, 3): '7:25 a.m.',
#  (1615, 3): '7:05 a.m.',
#  (1620, 3): '6:59 a.m.',
#  (1621, 3): '8:35 a.m.',
#  (1622, 3): '2:30 p.m.',
#  (1628, 3): '7:35 a.m.',
#  (1630, 3): '9:05 a.m.',
#  (1631, 3): '7:10 a.m.',
#  (1632, 3): '8:35 a.m.',
#  (1633, 3): '11:25 a.m.',
#  (1636, 3): '6:45 a.m.',
#  (1642, 3): '8:00 p.m.',
#  (1643, 3): '4:16 p.m.',
#  (1645, 3): '6:45 p.m.',
#  (1649, 3): '4:00 p.m.',
#  (1650, 3): '11:55 p.m.',
#  (1651, 3): '11:25 a.m.',
#  (1653, 3): '7:45 p.m.',
#  (1655, 3): '11:08 p.m.',
#  (1657, 3): '12:57 p.m.',
#  (1660, 3): '1:55 p.m.',
#  (1759, 3): '7:00 p.m.',
#  (1762, 3): '8:41 a.m.',
#  (1766, 3): '11:25 a.m.',
#  (1767, 3): '10:39 a.m.',
#  (1769, 3): '6:00 a.m.',
#  (1770, 3): '12:30 a.m.',
#  (1772, 3): '7:35 a.m.',
#  (1773, 3): '9:45 a.m.',
#  (1778, 3): '10:45 a.m.',
#  (1779, 3): '2:30 p.m.',
#  (1780, 3): '8:05 a.m.',
#  (1781, 3): '2:55 p.m.',
#  (1783, 3): '11:40 a.m.',
#  (1786, 3): '6:00 a.m.',
#  (1787, 3): '8:40 a.m.',
#  (1790, 3): '7:53 a.m.',
#  (1791, 3): '12:30 p.m.',
#  (1792, 3): '11:45 a.m.',
#  (1795, 3): '5:25 p.m.',
#  (1796, 3): '7:10 p.m.',
#  (1798, 3): '12:57 p.m.',
#  (1799, 3): '3:35 p.m.',
#  (1804, 3): '1:55 p.m.',
#  (1808, 3): '4:55 p.m.',
#  (1810, 3): '4:16 p.m.',
#  (1812, 3): '10:25 a.m.',
#  (1813, 3): '7:05 a.m.',
#  (1814, 3): '10:40 a.m.',
#  (1817, 3): '1:29 p.m.',
#  (1824, 3): '8:29 a.m.',
#  (1826, 3): '2:53 p.m.',
#  (1827, 3): '7:35 a.m.',
#  (1830, 3): '1:45 p.m.',
#  (1831, 3): '11:15 a.m.',
#  (1832, 3): '8:20 p.m.',
#  (1833, 3): '2:55 p.m.',
#  (1834, 3): '2:30 p.m.',
#  (1835, 3): '8:55 a.m.',
#  (1841, 3): '9:05 a.m.',
#  (1843, 3): '8:35 a.m.',
#  (1846, 3): '11:25 a.m.',
#  (1850, 3): '2:55 p.m.',
#  (1951, 3): '7:00 p.m.',
#  (1954, 3): '8:41 a.m.',
#  (1958, 3): '11:25 a.m.',
#  (1959, 3): '10:39 a.m.',
#  (1961, 3): '6:00 a.m.',
#  (1962, 3): '12:30 a.m.',
#  (1964, 3): '7:35 a.m.',
#  (1965, 3): '9:45 a.m.',
#  (1967, 3): '8:15 a.m.',
#  (1970, 3): '10:45 a.m.',
#  (1971, 3): '2:30 p.m.',
#  (1972, 3): '8:05 a.m.',
#  (1973, 3): '2:55 p.m.',
#  (1975, 3): '11:40 a.m.',
#  (1978, 3): '6:00 a.m.',
#  (1979, 3): '8:40 a.m.',
#  (1982, 3): '7:53 a.m.',
#  (1983, 3): '12:30 p.m.',
#  (1984, 3): '11:45 a.m.',
#  (1987, 3): '5:25 p.m.',
#  (1988, 3): '7:10 p.m.',
#  (1990, 3): '12:57 p.m.',
#  (1991, 3): '3:35 p.m.',
#  (1996, 3): '1:55 p.m.',
#  (2000, 3): '4:55 p.m.',
#  (2002, 3): '4:16 p.m.',
#  (2004, 3): '10:25 a.m.',
#  (2005, 3): '7:05 a.m.',
#  (2009, 3): '1:29 p.m.',
#  (2016, 3): '8:29 a.m.',
#  (2018, 3): '2:53 p.m.',
#  (2019, 3): '7:35 a.m.',
#  (2022, 3): '1:45 p.m.',
#  (2023, 3): '11:15 a.m.',
#  (2024, 3): '8:20 p.m.',
#  (2025, 3): '2:55 p.m.',
#  (2026, 3): '2:30 p.m.',
#  (2027, 3): '8:55 a.m.',
#  (2033, 3): '9:05 a.m.',
#  (2035, 3): '8:35 a.m.',
#  (2038, 3): '11:25 a.m.',
#  (2042, 3): '2:55 p.m.',
#  (2051, 3): '7:00 p.m.',
#  (2054, 3): '8:41 a.m.',
#  (2058, 3): '11:25 a.m.',
#  (2059, 3): '10:39 a.m.',
#  (2061, 3): '6:00 a.m.',
#  (2062, 3): '12:30 a.m.',
#  (2064, 3): '7:35 a.m.',
#  (2065, 3): '9:45 a.m.',
#  (2067, 3): '8:15 a.m.',
#  (2070, 3): '10:45 a.m.',
#  (2071, 3): '2:30 p.m.',
#  (2072, 3): '8:05 a.m.',
#  (2073, 3): '2:55 p.m.',
#  (2075, 3): '11:40 a.m.',
#  (2078, 3): '6:00 a.m.',
#  (2079, 3): '8:40 a.m.',
#  (2082, 3): '7:53 a.m.',
#  (2083, 3): '12:30 p.m.',
#  (2084, 3): '11:45 a.m.',
#  (2087, 3): '5:25 p.m.',
#  (2088, 3): '7:10 p.m.',
#  (2090, 3): '12:57 p.m.',
#  (2091, 3): '3:35 p.m.',
#  (2096, 3): '1:55 p.m.',
#  (2100, 3): '4:55 p.m.',
#  (2102, 3): '4:16 p.m.',
#  (2104, 3): '10:25 a.m.',
#  (2105, 3): '7:05 a.m.',
#  (2106, 3): '10:40 a.m.',
#  (2109, 3): '1:29 p.m.',
#  (2116, 3): '8:29 a.m.',
#  (2118, 3): '2:53 p.m.',
#  (2119, 3): '7:35 a.m.',
#  (2122, 3): '1:45 p.m.',
#  (2123, 3): '11:15 a.m.',
#  (2124, 3): '8:20 p.m.',
#  (2125, 3): '2:55 p.m.',
#  (2126, 3): '2:30 p.m.',
#  (2127, 3): '8:55 a.m.',
#  (2133, 3): '9:05 a.m.',
#  (2135, 3): '8:35 a.m.',
#  (2138, 3): '11:25 a.m.',
#  (2142, 3): '2:55 p.m.',
#  (2151, 3): '11:40 a.m.',
#  (2152, 3): '9:00 p.m.',
#  (2154, 3): '1:05 p.m.',
#  (2156, 3): '7:00 p.m.',
#  (2159, 3): '8:41 a.m.',
#  (2163, 3): '11:25 a.m.',
#  (2164, 3): '10:39 a.m.',
#  (2166, 3): '6:00 a.m.',
#  (2167, 3): '12:30 a.m.',
#  (2169, 3): '7:35 a.m.',
#  (2170, 3): '9:45 a.m.',
#  (2172, 3): '8:15 a.m.',
#  (2175, 3): '10:45 a.m.',
#  (2176, 3): '2:30 p.m.',
#  (2177, 3): '8:05 a.m.',
#  (2178, 3): '2:55 p.m.',
#  (2180, 3): '11:40 a.m.',
#  (2183, 3): '6:00 a.m.',
#  (2184, 3): '8:40 a.m.',
#  (2187, 3): '7:53 a.m.',
#  (2188, 3): '12:30 p.m.',
#  (2189, 3): '11:45 a.m.',
#  (2192, 3): '5:25 p.m.',
#  (2193, 3): '7:10 p.m.',
#  (2195, 3): '12:57 p.m.',
#  (2196, 3): '3:35 p.m.',
#  (2201, 3): '1:55 p.m.',
#  (2205, 3): '4:55 p.m.',
#  (2207, 3): '4:16 p.m.',
#  (2209, 3): '10:25 a.m.',
#  (2210, 3): '7:05 a.m.',
#  (2214, 3): '1:29 p.m.',
#  (2221, 3): '8:29 a.m.',
#  (2223, 3): '2:53 p.m.',
#  (2224, 3): '7:35 a.m.',
#  (2227, 3): '1:45 p.m.',
#  (2228, 3): '11:15 a.m.',
#  (2229, 3): '8:20 p.m.',
#  (2230, 3): '2:55 p.m.',
#  (2231, 3): '2:30 p.m.',
#  (2232, 3): '8:55 a.m.',
#  (2240, 3): '8:35 a.m.',
#  (2243, 3): '11:25 a.m.',
#  (2247, 3): '2:55 p.m.',
#  (5, 4): '11:25 p.m.',
#  (190, 4): '1:32 p.m.',
#  (232, 4): '8:04 a.m.',
#  (506, 4): '7:27 a.m.',
#  (688, 4): '1:48 p.m.',
#  (800, 4): '12:12 p.m.',
#  (809, 4): '7:21 a.m.',
#  (945, 4): '2:26 p.m.',
#  (1043, 4): '1:30 p.m.',
#  (1183, 4): '10:18 a.m.',
#  (1249, 4): '6:08 a.m.',
#  (1340, 4): '8:12 a.m.',
#  (1676, 4): '8:04 a.m.',
#  (2238, 4): '8:52 a.m.',
#  (0, 4): '7:02 a.m.',
#  (3, 4): '6:40 a.m.',
#  (6, 4): '7:04 a.m.',
#  (10, 4): '11:05 a.m.',
#  (11, 4): '8:04 a.m.',
#  (15, 4): '9:59 a.m.',
#  (20, 4): '10:46 a.m.',
#  (25, 4): '5:59 a.m.',
#  (27, 4): '5:38 p.m.',
#  (35, 4): '8:31 a.m.',
#  (44, 4): '3:38 p.m.',
#  (49, 4): '7:14 a.m.',
#  (52, 4): '7:29 a.m.',
#  (62, 4): '12:58 a.m.',
#  (64, 4): '7:29 a.m.',
#  (81, 4): '1:19 p.m.',
#  (88, 4): '8:25 p.m.',
#  (98, 4): '9:58 a.m.',
#  (101, 4): '5:38 p.m.',
#  (116, 4): '7:04 a.m.',
#  (136, 4): '1:19 p.m.',
#  (143, 4): '11:43 a.m.',
#  (144, 4): '11:05 a.m.',
#  (170, 4): '11:05 a.m.',
#  (182, 4): '9:59 a.m.',
#  (186, 4): '11:56 a.m.',
#  (198, 4): '5:59 a.m.',
#  (200, 4): '2:38 p.m.',
#  (201, 4): '3:38 p.m.',
#  (229, 4): '11:55 a.m.',
#  (244, 4): '11:05 a.m.',
#  (266, 4): '8:12 a.m.',
#  (269, 4): '12:12 p.m.',
#  (277, 4): '1:19 p.m.',
#  (278, 4): '12:58 a.m.',
#  (291, 4): '9:58 a.m.',
#  (299, 4): '12:42 p.m.',
#  (308, 4): '8:26 a.m.',
#  (314, 4): '8:39 p.m.',
#  (321, 4): '12:10 p.m.',
#  (324, 4): '1:19 p.m.',
#  (326, 4): '8:55 a.m.',
#  (330, 4): '11:43 a.m.',
#  (339, 4): '7:29 a.m.',
#  (349, 4): '12:58 a.m.',
#  (351, 4): '7:29 a.m.',
#  (368, 4): '1:19 p.m.',
#  (375, 4): '8:25 p.m.',
#  (385, 4): '9:58 a.m.',
#  (388, 4): '5:38 p.m.',
#  (403, 4): '7:04 a.m.',
#  (423, 4): '1:19 p.m.',
#  (430, 4): '11:43 a.m.',
#  (431, 4): '11:05 a.m.',
#  (438, 4): '7:14 p.m.',
#  (439, 4): '6:40 a.m.',
#  (441, 4): '8:42 a.m.',
#  (445, 4): '11:32 a.m.',
#  (455, 4): '7:04 a.m.',
#  (457, 4): '11:05 a.m.',
#  (462, 4): '11:56 a.m.',
#  (470, 4): '12:35 p.m.',
#  (473, 4): '11:56 a.m.',
#  (476, 4): '10:46 a.m.',
#  (477, 4): '11:55 a.m.',
#  (485, 4): '5:59 a.m.',
#  (487, 4): '2:38 p.m.',
#  (502, 4): '8:31 a.m.',
#  (516, 4): '11:55 a.m.',
#  (519, 4): '8:04 a.m.',
#  (531, 4): '11:05 a.m.',
#  (533, 4): '3:38 p.m.',
#  (535, 4): '7:14 a.m.',
#  (537, 4): '7:02 a.m.',
#  (539, 4): '6:40 a.m.',
#  (553, 4): '7:04 a.m.',
#  (556, 4): '9:59 a.m.',
#  (565, 4): '8:04 a.m.',
#  (575, 4): '10:46 a.m.',
#  (576, 4): '11:55 a.m.',
#  (583, 4): '2:38 p.m.',
#  (585, 4): '5:59 a.m.',
#  (587, 4): '5:38 p.m.',
#  (603, 4): '8:31 a.m.',
#  (620, 4): '3:38 p.m.',
#  (626, 4): '3:38 p.m.',
#  (628, 4): '7:14 a.m.',
#  (630, 4): '7:14 p.m.',
#  (631, 4): '6:40 a.m.',
#  (633, 4): '8:42 a.m.',
#  (637, 4): '11:32 a.m.',
#  (647, 4): '7:04 a.m.',
#  (649, 4): '11:05 a.m.',
#  (654, 4): '11:56 a.m.',
#  (662, 4): '12:35 p.m.',
#  (665, 4): '11:56 a.m.',
#  (668, 4): '10:46 a.m.',
#  (669, 4): '11:55 a.m.',
#  (677, 4): '5:59 a.m.',
#  (679, 4): '2:38 p.m.',
#  (694, 4): '8:31 a.m.',
#  ...}
