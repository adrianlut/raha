# %% [markdown]
# # End-to-End Data Cleaning Pipeline with Raha and Baran (Minimal and Integrated)
# We build an end-to-end data cleaning pipeline with our configuration-free error detection and correction systems, Raha and Baran.

# %%
import pandas
import IPython.display
import ipywidgets

import raha

# %% [markdown]
# ## 1. Instantiating the Detection and Correction Classes
# We first instantiate the `Detection` and `Correction` classes.

# %%
app_1 = raha.Detection()
app_2 = raha.Correction()

# How many tuples would you label?
app_1.LABELING_BUDGET = 20
app_2.LABELING_BUDGET = 0

# Would you like to see the logs?
app_1.VERBOSE = True
app_2.VERBOSE = True

# %% [markdown]
# ## 2. Instantiating the Dataset
# We next load and instantiate the dataset object.

# %%
dataset_dictionary = {
        "name": "beers",
        "path": "datasets/beers/dirty.csv",
        "clean_path": "datasets/beers/clean.csv"
    }
d = app_1.initialize_dataset(dataset_dictionary)
d.dataframe.head()
# Out:
#   index    id            beer_name                           style  \
# 0     1  1436             Pub Beer             American Pale Lager
# 1     2  2265          Devil's Cup         American Pale Ale (APA)
# 2     3  2264  Rise of the Phoenix                    American IPA
# 3     4  2263             Sinister  American Double / Imperial IPA
# 4     5  2262        Sex and Candy                    American IPA
#
#        ounces    abv  ibu brewery_id               brewery_name  city state
# 0     12.0 oz   0.05  N/A        408  10 Barrel Brewing Company  Bend    OR
# 1    12.0 oz.  0.066  N/A        177        18th Street Brewery  Gary    IN
# 2  12.0 ounce  0.071  N/A        177        18th Street Brewery  Gary    IN
# 3     12.0 oz  0.09%  N/A        177        18th Street Brewery  Gary    IN
# 4    12.0 OZ.  0.075  N/A        177        18th Street Brewery  Gary    IN

# %% [markdown]
# ## 3. Generating Features and Clusters
# Raha runs (all or the promising) error detection strategies on the dataset. This step could take a while because all the strategies should be run on the dataset. Raha then generates a feature vector for each data cell based on the output of error detection strategies. Raha next builds a hierarchical clustering model for our clustering-based sampling approach.

# %%
app_1.run_strategies(d)
app_1.generate_features(d)
app_1.build_clusters(d)
# Out:
# 23 cells are detected by ["PVD", ["city", "J"]].2348 cells are detected by ["PVD", ["abv", "."]].
#
# 91 cells are detected by ["PVD", ["state", "P"]].
# 18 cells are detected by ["PVD", ["style", "j"]].
# 15 cells are detected by ["PVD", ["style", "v"]].
# 7 cells are detected by ["PVD", ["state", "J"]].
# 126 cells are detected by ["PVD", ["brewery_name", "N"]].
# 797 cells are detected by ["PVD", ["brewery_name", "l"]].
# 4 cells are detected by ["PVD", ["brewery_name", "q"]].
# 974 cells are detected by ["PVD", ["city", "l"]].
# 4810 cells are detected by ["RVD", ["ounces", "style"]].0 cells are detected by ["RVD", ["index", "abv"]].
#
# 278 cells are detected by ["PVD", ["beer_name", "("]].275 cells are detected by ["PVD", ["brewery_name", "v"]].
#
# 1093 cells are detected by ["PVD", ["id", "2"]].
# 1005 cells are detected by ["PVD", ["ibu", "A"]].
# 2299 cells are detected by ["PVD", ["brewery_name", "B"]].
# 874 cells are detected by ["PVD", ["beer_name", "P"]].
# 190 cells are detected by ["PVD", ["beer_name", "F"]].
# 1 cells are detected by ["PVD", ["beer_name", "\u00e4"]].
# 4434 cells are detected by ["RVD", ["brewery_id", "style"]].
# 267 cells are detected by ["PVD", ["style", "S"]].
# 455 cells are detected by ["PVD", ["style", "B"]].
# 2 cells are detected by ["PVD", ["beer_name", "/"]].4656 cells are detected by ["RVD", ["abv", "city"]].
#
# 619 cells are detected by ["PVD", ["index", "9"]].
# 13 cells are detected by ["PVD", ["beer_name", "&"]].
# 124 cells are detected by ["PVD", ["beer_name", "N"]].
# 1689 cells are detected by ["PVD", ["style", "c"]].
# 619 cells are detected by ["PVD", ["index", "0"]].
# 619 cells are detected by ["PVD", ["index", "6"]].
# 610 cells are detected by ["PVD", ["id", "7"]].
# 0 cells are detected by ["RVD", ["index", "style"]].
# 693 cells are detected by ["PVD", ["abv", "%"]].
# 89 cells are detected by ["PVD", ["style", "H"]].
# 2382 cells are detected by ["PVD", ["ounces", "1"]].
# 154 cells are detected by ["PVD", ["ounces", "Z"]].
# 267 cells are detected by ["PVD", ["city", "y"]].
# 4782 cells are detected by ["RVD", ["style", "abv"]].
# 4448 cells are detected by ["RVD", ["brewery_name", "style"]].
# 0 cells are detected by ["RVD", ["index", "state"]].
# 214 cells are detected by ["RVD", ["beer_name", "abv"]].
# 21 cells are detected by ["PVD", ["brewery_name", "4"]].
# 0 cells are detected by ["RVD", ["id", "city"]].
# 4434 cells are detected by ["RVD", ["brewery_name", "ounces"]].
# 2 cells are detected by ["PVD", ["brewery_name", ","]].
# 601 cells are detected by ["PVD", ["beer_name", "c"]].
# 642 cells are detected by ["PVD", ["beer_name", "h"]].
# 86 cells are detected by ["PVD", ["city", "E"]].
# 4566 cells are detected by ["RVD", ["brewery_id", "id"]].
# 4566 cells are detected by ["RVD", ["state", "beer_name"]].
# 165 cells are detected by ["PVD", ["style", "k"]].
# 3984 cells are detected by ["RVD", ["city", "ibu"]].
# 1689 cells are detected by ["PVD", ["style", "m"]].
# 4776 cells are detected by ["RVD", ["style", "brewery_name"]].
# 0 cells are detected by ["RVD", ["brewery_id", "state"]].
# 2023 cells are detected by ["PVD", ["beer_name", "e"]].
# 68 cells are detected by ["PVD", ["beer_name", "3"]].
# 431 cells are detected by ["PVD", ["brewery_name", "k"]].
# 129 cells are detected by ["PVD", ["city", "R"]].
# 25 cells are detected by ["PVD", ["city", "z"]].
# 100 cells are detected by ["PVD", ["brewery_name", "D"]].
# 2025 cells are detected by ["PVD", ["brewery_name", "i"]].
# 4734 cells are detected by ["RVD", ["ibu", "style"]].
# 0 cells are detected by ["RVD", ["id", "ibu"]].
# 57 cells are detected by ["PVD", ["beer_name", "-"]].
# 3 cells are detected by ["PVD", ["beer_name", "\u00e9"]].
# 104 cells are detected by ["PVD", ["brewery_name", "V"]].
# 4788 cells are detected by ["RVD", ["ibu", "beer_name"]].72 cells are detected by ["RVD", ["beer_name", "state"]].
#
# 315 cells are detected by ["PVD", ["city", "B"]].629 cells are detected by ["PVD", ["index", "4"]].
# 1312 cells are detected by ["PVD", ["beer_name", "i"]].
#
# 1505 cells are detected by ["PVD", ["beer_name", "r"]].205 cells are detected by ["PVD", ["beer_name", "M"]].
#
# 587 cells are detected by ["PVD", ["brewery_id", "5"]].
# 29 cells are detected by ["PVD", ["city", "x"]].
# 26 cells are detected by ["PVD", ["state", "U"]].
# 253 cells are detected by ["PVD", ["beer_name", "R"]].
# 4790 cells are detected by ["RVD", ["style", "beer_name"]].
# 162 cells are detected by ["PVD", ["style", "w"]].
# 0 cells are detected by ["RVD", ["id", "state"]].
# 4462 cells are detected by ["RVD", ["city", "style"]].
# 359 cells are detected by ["PVD", ["city", "S"]].339 cells are detected by ["PVD", ["beer_name", "H"]].
#
# 14 cells are detected by ["PVD", ["brewery_name", "8"]].2406 cells are detected by ["PVD", ["brewery_name", " "]].
#
# 62 cells are detected by ["PVD", ["city", "N"]].219 cells are detected by ["PVD", ["ibu", "6"]].
#
# 1573 cells are detected by ["PVD", ["brewery_name", "p"]].139 cells are detected by ["PVD", ["abv", "1"]].
#
# 112 cells are detected by ["PVD", ["beer_name", "E"]].
# 242 cells are detected by ["PVD", ["city", "L"]].
# 1368 cells are detected by ["PVD", ["beer_name", "o"]].
# 140 cells are detected by ["PVD", ["ounces", "i"]].
# 378 cells are detected by ["RVD", ["beer_name", "index"]].
# 1 cells are detected by ["PVD", ["beer_name", "?"]].
# 1191 cells are detected by ["PVD", ["style", "P"]].
# 4778 cells are detected by ["RVD", ["ibu", "brewery_name"]].
# 37 cells are detected by ["PVD", ["brewery_name", "I"]].
# 4782 cells are detected by ["RVD", ["ibu", "abv"]].
# 178 cells are detected by ["PVD", ["abv", "3"]].
# 4810 cells are detected by ["RVD", ["ounces", "id"]].
# 42 cells are detected by ["PVD", ["style", "\u00f6"]].
# 428 cells are detected by ["PVD", ["city", "h"]].
# 7 cells are detected by ["PVD", ["style", "\u00e8"]].4776 cells are detected by ["RVD", ["style", "brewery_id"]].
#
# 46 cells are detected by ["PVD", ["beer_name", "J"]].
# 273 cells are detected by ["PVD", ["city", "m"]].
# 265 cells are detected by ["PVD", ["ibu", "3"]].
# 56 cells are detected by ["PVD", ["state", "F"]].
# 1131 cells are detected by ["OD", ["histogram", "0.9", "0.1"]].
# 1171 cells are detected by ["PVD", ["abv", "5"]].
# 246 cells are detected by ["PVD", ["state", "T"]].
# 4656 cells are detected by ["RVD", ["abv", "brewery_id"]].
# 85 cells are detected by ["PVD", ["beer_name", "K"]].
# 4562 cells are detected by ["RVD", ["state", "abv"]].
# 4566 cells are detected by ["RVD", ["state", "style"]].
# 4790 cells are detected by ["RVD", ["style", "id"]].
# 681 cells are detected by ["PVD", ["id", "4"]].
# 120 cells are detected by ["PVD", ["city", "b"]].
# 1631 cells are detected by ["OD", ["gaussian", "2.0"]].
# 522 cells are detected by ["PVD", ["state", "C"]].
# 23 cells are detected by ["PVD", ["ounces", "4"]].
# 1784 cells are detected by ["PVD", ["style", "A"]].
# 619 cells are detected by ["PVD", ["index", "8"]].
# 602 cells are detected by ["PVD", ["id", "8"]].
# 33 cells are detected by ["PVD", ["beer_name", "5"]].
# 547 cells are detected by ["PVD", ["abv", "4"]].
# 9 cells are detected by ["PVD", ["brewery_name", "("]].
# 12969 cells are detected by ["OD", ["histogram", "0.9", "0.7"]].
# 2345 cells are detected by ["PVD", ["style", "e"]].
# 111 cells are detected by ["PVD", ["city", "F"]].
# 810 cells are detected by ["PVD", ["brewery_id", "3"]].
# 270 cells are detected by ["PVD", ["beer_name", "L"]].
# 75 cells are detected by ["PVD", ["state", "V"]].
# 566 cells are detected by ["PVD", ["brewery_name", "u"]].
# 541 cells are detected by ["PVD", ["beer_name", "B"]].
# 1 cells are detected by ["PVD", ["brewery_name", "9"]].
# 581 cells are detected by ["PVD", ["ounces", "n"]].
# 4440 cells are detected by ["RVD", ["brewery_name", "abv"]].
# 0 cells are detected by ["RVD", ["id", "ounces"]].
# 1899 cells are detected by ["PVD", ["brewery_name", "o"]].
# 1453 cells are detected by ["PVD", ["city", "n"]].
# 16260 cells are detected by ["OD", ["histogram", "0.3", "0.7"]].
# 10 cells are detected by ["PVD", ["city", "'"]].
# 1302 cells are detected by ["OD", ["gaussian", "2.7"]].
# 16 cells are detected by ["PVD", ["city", "Y"]].
# 4692 cells are detected by ["RVD", ["style", "ibu"]].
# 4788 cells are detected by ["RVD", ["ibu", "index"]].
# 247 cells are detected by ["PVD", ["brewery_name", "M"]].
# 4774 cells are detected by ["RVD", ["ibu", "state"]].
# 346 cells are detected by ["RVD", ["beer_name", "ounces"]].83 cells are detected by ["PVD", ["city", "f"]].
#
# 221 cells are detected by ["PVD", ["city", "P"]].175 cells are detected by ["PVD", ["beer_name", "'"]].
#
# 8 cells are detected by ["PVD", ["brewery_name", "5"]].
# 54 cells are detected by ["PVD", ["city", "O"]].
# 2410 cells are detected by ["PVD", ["ounces", " "]].
# 2080 cells are detected by ["PVD", ["brewery_name", "n"]].
# 1463 cells are detected by ["OD", ["gaussian", "2.5"]].
# 1443 cells are detected by ["PVD", ["beer_name", "l"]].
# 1194 cells are detected by ["PVD", ["city", "e"]].
# 39 cells are detected by ["PVD", ["brewery_name", "1"]].
# 256 cells are detected by ["PVD", ["beer_name", "2"]].
# 9061 cells are detected by ["OD", ["histogram", "0.5", "0.5"]].
# 30 cells are detected by ["PVD", ["beer_name", "8"]].
# 2150 cells are detected by ["PVD", ["style", " "]].
# 9061 cells are detected by ["OD", ["histogram", "0.3", "0.5"]].
# 16260 cells are detected by ["OD", ["histogram", "0.1", "0.7"]].
# 169 cells are detected by ["PVD", ["state", "L"]].
# 4 cells are detected by ["PVD", ["style", "Q"]].
# 4532 cells are detected by ["RVD", ["city", "id"]].
# 72 cells are detected by ["PVD", ["city", "I"]].
# 434 cells are detected by ["RVD", ["city", "state"]].
# 395 cells are detected by ["PVD", ["beer_name", "k"]].
# 34 cells are detected by ["PVD", ["beer_name", "9"]].
# 11 cells are detected by ["PVD", ["ounces", "a"]].
# 502 cells are detected by ["PVD", ["brewery_name", "d"]].
# 84 cells are detected by ["PVD", ["style", "M"]].
# 4738 cells are detected by ["OD", ["gaussian", "1.3"]].
# 250 cells are detected by ["PVD", ["beer_name", "D"]].
# 565 cells are detected by ["PVD", ["state", "I"]].
# 4526 cells are detected by ["RVD", ["state", "city"]].
# 3 cells are detected by ["PVD", ["style", "Z"]].
# 11 cells are detected by ["PVD", ["ounces", "C"]].
# 3266 cells are detected by ["KBVD", "/home/adrian/source/MA/raha/raha/tools/KATARA/knowledge-base/zipHasCity.rel.txt"].
# 3604 cells are detected by ["RVD", ["brewery_name", "ibu"]].
# 4776 cells are detected by ["RVD", ["style", "state"]].282 cells are detected by ["PVD", ["style", ")"]].
#
# 132 cells are detected by ["PVD", ["brewery_name", "W"]].
# 842 cells are detected by ["PVD", ["ounces", "6"]].7 cells are detected by ["PVD", ["brewery_name", "j"]].
#
# 382 cells are detected by ["PVD", ["style", "g"]].1050 cells are detected by ["PVD", ["brewery_name", "t"]].
#
# 893 cells are detected by ["PVD", ["city", "s"]].
# 359 cells are detected by ["PVD", ["city", "C"]].
# 32 cells are detected by ["PVD", ["style", "x"]].
# 2 cells are detected by ["PVD", ["brewery_name", "Q"]].
# 4664 cells are detected by ["RVD", ["abv", "ounces"]].
# 52 cells are detected by ["RVD", ["beer_name", "ibu"]].
# 4668 cells are detected by ["RVD", ["abv", "id"]].
# 350 cells are detected by ["PVD", ["beer_name", "C"]].
# 4626 cells are detected by ["RVD", ["abv", "ibu"]].15 cells are detected by ["PVD", ["beer_name", "\u2019"]].
#
# 154 cells are detected by ["PVD", ["ounces", "O"]].2033 cells are detected by ["PVD", ["brewery_name", "a"]].
#
# 50 cells are detected by ["PVD", ["state", "E"]].
# 489 cells are detected by ["PVD", ["style", "/"]].
# 229 cells are detected by ["PVD", ["brewery_name", "T"]].
# 403 cells are detected by ["PVD", ["style", "u"]].
# 432 cells are detected by ["PVD", ["state", "M"]].
# 129 cells are detected by ["PVD", ["ounces", "-"]].
# 4566 cells are detected by ["RVD", ["state", "index"]].
# 439 cells are detected by ["PVD", ["beer_name", "y"]].
# 19546 cells are detected by ["OD", ["histogram", "0.7", "0.9"]].1295 cells are detected by ["OD", ["histogram", "0.5", "0.1"]].419 cells are detected by ["PVD", ["city", "u"]].
#
#
# 432 cells are detected by ["PVD", ["abv", "7"]].
# 282 cells are detected by ["PVD", ["style", "("]].
# 33 cells are detected by ["PVD", ["brewery_name", "2"]].
# 1623 cells are detected by ["PVD", ["beer_name", "a"]].
# 4426 cells are detected by ["RVD", ["brewery_id", "abv"]].
# 613 cells are detected by ["PVD", ["style", "I"]].
# 14 cells are detected by ["PVD", ["state", "G"]].
# 0 cells are detected by ["RVD", ["index", "id"]].
# 81 cells are detected by ["PVD", ["state", "H"]].
# 4554 cells are detected by ["RVD", ["brewery_id", "beer_name"]].
# 461 cells are detected by ["PVD", ["beer_name", "g"]].
# 956 cells are detected by ["PVD", ["brewery_id", "1"]].
# 214 cells are detected by ["PVD", ["style", "W"]].
# 4552 cells are detected by ["RVD", ["state", "ibu"]].
# 167 cells are detected by ["PVD", ["state", "W"]].
# 685 cells are detected by ["PVD", ["id", "5"]].
# 1750 cells are detected by ["RVD", ["brewery_name", "city"]].
# 56 cells are detected by ["PVD", ["beer_name", "U"]].4526 cells are detected by ["RVD", ["state", "brewery_id"]].
#
# 379 cells are detected by ["PVD", ["brewery_id", "9"]].
# 171 cells are detected by ["PVD", ["brewery_name", "f"]].
# 20 cells are detected by ["PVD", ["city", "q"]].
# 317 cells are detected by ["PVD", ["abv", "9"]].
# 4566 cells are detected by ["RVD", ["brewery_id", "index"]].
# 2 cells are detected by ["PVD", ["beer_name", "\u00ed"]].
# 21951 cells are detected by ["OD", ["histogram", "0.5", "0.9"]].
# 1176 cells are detected by ["PVD", ["city", "i"]].
# 199 cells are detected by ["PVD", ["beer_name", "f"]].
# 103 cells are detected by ["PVD", ["style", "E"]].
# 112 cells are detected by ["PVD", ["style", "z"]].
# 380 cells are detected by ["PVD", ["brewery_id", "8"]].
# 380 cells are detected by ["PVD", ["ibu", "0"]].
# 16 cells are detected by ["PVD", ["beer_name", "\u00f6"]].
# 11 cells are detected by ["PVD", ["style", "T"]].
# 170 cells are detected by ["PVD", ["brewery_name", "F"]].
# 1084 cells are detected by ["PVD", ["city", "r"]].
# 221 cells are detected by ["PVD", ["city", "k"]].
# 8218 cells are detected by ["OD", ["histogram", "0.7", "0.5"]].
# 322 cells are detected by ["PVD", ["city", "c"]].
# 3584 cells are detected by ["RVD", ["brewery_id", "ibu"]].
# 4810 cells are detected by ["RVD", ["ounces", "brewery_id"]].
# 5 cells are detected by ["PVD", ["ounces", "3"]].
# 140 cells are detected by ["PVD", ["ounces", "l"]].
# 485 cells are detected by ["PVD", ["brewery_name", "h"]].
# 1295 cells are detected by ["OD", ["histogram", "0.1", "0.1"]].
# 280 cells are detected by ["PVD", ["abv", "2"]].
# 30 cells are detected by ["PVD", ["style", "\u00e4"]].
# 93 cells are detected by ["PVD", ["ibu", "9"]].
# 162 cells are detected by ["RVD", ["brewery_name", "brewery_id"]].
# 186 cells are detected by ["PVD", ["ibu", "7"]].109 cells are detected by ["PVD", ["style", "F"]].
#
# 376 cells are detected by ["PVD", ["style", "s"]].
# 1372 cells are detected by ["PVD", ["id", "1"]].
# 692 cells are detected by ["PVD", ["id", "6"]].
# 4568 cells are detected by ["RVD", ["brewery_name", "beer_name"]].
# 7332 cells are detected by ["OD", ["histogram", "0.9", "0.5"]].
# 5388 cells are detected by ["OD", ["histogram", "0.7", "0.3"]].
# 150 cells are detected by ["PVD", ["beer_name", "v"]].
# 4778 cells are detected by ["RVD", ["ibu", "city"]].
# 52 cells are detected by ["PVD", ["style", "O"]].
# 1448 cells are detected by ["PVD", ["city", "a"]].
# 725 cells are detected by ["PVD", ["beer_name", "d"]].
# 30 cells are detected by ["PVD", ["city", "K"]].
# 4782 cells are detected by ["RVD", ["style", "ounces"]].
# 289 cells are detected by ["PVD", ["beer_name", "W"]].
# 21951 cells are detected by ["OD", ["histogram", "0.3", "0.9"]].
# 82 cells are detected by ["PVD", ["city", "T"]].
# 2393 cells are detected by ["PVD", ["ounces", "0"]].14754 cells are detected by ["OD", ["histogram", "0.9", "0.9"]].
#
# 5 cells are detected by ["PVD", ["beer_name", "X"]].
# 14 cells are detected by ["PVD", ["city", "U"]].
# 1295 cells are detected by ["OD", ["histogram", "0.3", "0.1"]].
# 49 cells are detected by ["PVD", ["style", "y"]].
# 4810 cells are detected by ["RVD", ["ounces", "index"]].
# 3 cells are detected by ["PVD", ["brewery_name", "X"]].
# 92 cells are detected by ["RVD", ["beer_name", "brewery_name"]].
# 1430 cells are detected by ["PVD", ["index", "1"]].
# 570 cells are detected by ["PVD", ["ounces", "c"]].
# 2192 cells are detected by ["PVD", ["beer_name", " "]].
# 4580 cells are detected by ["RVD", ["brewery_name", "index"]].
# 181 cells are detected by ["PVD", ["brewery_name", "P"]].
# 92 cells are detected by ["RVD", ["beer_name", "brewery_id"]].
# 378 cells are detected by ["RVD", ["beer_name", "id"]].
# 278 cells are detected by ["PVD", ["beer_name", ")"]].
# 572 cells are detected by ["PVD", ["beer_name", "S"]].
# 1396 cells are detected by ["PVD", ["city", "o"]].
# 7633 cells are detected by ["OD", ["gaussian", "1.0"]].
# 104 cells are detected by ["PVD", ["state", "Y"]].
# 244 cells are detected by ["PVD", ["beer_name", "T"]].
# 175 cells are detected by ["PVD", ["brewery_name", "G"]].
# 2 cells are detected by ["PVD", ["beer_name", "\u00fc"]].
# 453 cells are detected by ["PVD", ["city", "g"]].
# 1018 cells are detected by ["PVD", ["city", "t"]].
# 396 cells are detected by ["PVD", ["ibu", "2"]].
# 2256 cells are detected by ["PVD", ["ounces", "o"]].
# 2410 cells are detected by ["PVD", ["ounces", "."]].
# 114 cells are detected by ["PVD", ["city", "W"]].
# 1005 cells are detected by ["PVD", ["ibu", "N"]].
# 108 cells are detected by ["PVD", ["city", "w"]].
# 395 cells are detected by ["PVD", ["ibu", "5"]].
# 697 cells are detected by ["PVD", ["brewery_id", "4"]].
# 943 cells are detected by ["PVD", ["brewery_name", "s"]].
# 748 cells are detected by ["PVD", ["brewery_id", "2"]].
# 188 cells are detected by ["PVD", ["city", "D"]].
# 619 cells are detected by ["PVD", ["index", "5"]].
# 313 cells are detected by ["PVD", ["ibu", "1"]].
# 1558 cells are detected by ["PVD", ["brewery_name", "m"]].
# 3 cells are detected by ["PVD", ["brewery_name", "3"]].
# 9 cells are detected by ["PVD", ["beer_name", "Q"]].
# 49 cells are detected by ["PVD", ["beer_name", "4"]].
# 0 cells are detected by ["RVD", ["id", "style"]].
# 645 cells are detected by ["PVD", ["abv", "6"]].
# 619 cells are detected by ["PVD", ["index", "7"]].
# 2201 cells are detected by ["PVD", ["brewery_name", "w"]].
# 13855 cells are detected by ["OD", ["histogram", "0.7", "0.7"]].
# 1005 cells are detected by ["PVD", ["ibu", "/"]].
# 223 cells are detected by ["PVD", ["beer_name", "1"]].
# 149 cells are detected by ["PVD", ["state", "R"]].
# 238 cells are detected by ["PVD", ["city", "M"]].
# 666 cells are detected by ["PVD", ["id", "3"]].
# 85 cells are detected by ["PVD", ["brewery_name", "L"]].
# 84 cells are detected by ["PVD", ["brewery_name", "U"]].
# 5388 cells are detected by ["OD", ["histogram", "0.1", "0.3"]].
# 17 cells are detected by ["PVD", ["beer_name", "7"]].
# 4774 cells are detected by ["RVD", ["ibu", "ounces"]].
# 613 cells are detected by ["PVD", ["id", "9"]].
# 85 cells are detected by ["PVD", ["state", "K"]].
# 7 cells are detected by ["PVD", ["city", "X"]].68 cells are detected by ["PVD", ["beer_name", "x"]].
#
# 69 cells are detected by ["PVD", ["style", "V"]].
# 325 cells are detected by ["PVD", ["abv", "8"]].
# 2348 cells are detected by ["PVD", ["abv", "0"]].
# 0 cells are detected by ["RVD", ["id", "brewery_name"]].
# 8 cells are detected by ["PVD", ["brewery_name", "0"]].
# 72 cells are detected by ["PVD", ["brewery_name", "x"]].
# 2392 cells are detected by ["PVD", ["brewery_name", "r"]].
# 4652 cells are detected by ["RVD", ["abv", "state"]].
# 897 cells are detected by ["OD", ["gaussian", "3.0"]].
# 4790 cells are detected by ["RVD", ["style", "index"]].
# 512 cells are detected by ["PVD", ["beer_name", "m"]].4520 cells are detected by ["RVD", ["city", "beer_name"]].
#
# 377 cells are detected by ["PVD", ["state", "N"]].
# 18 cells are detected by ["PVD", ["beer_name", "q"]].
# 1964 cells are detected by ["PVD", ["style", "a"]].
# 472 cells are detected by ["PVD", ["state", "O"]].
# 700 cells are detected by ["PVD", ["index", "3"]].
# 4566 cells are detected by ["RVD", ["state", "id"]].
# 1686 cells are detected by ["PVD", ["ounces", "z"]].
# 0 cells are detected by ["RVD", ["id", "abv"]].
# 1 cells are detected by ["PVD", ["beer_name", "\u00e8"]].
# 4802 cells are detected by ["RVD", ["ounces", "state"]].
# 4788 cells are detected by ["RVD", ["ibu", "id"]].
# 46 cells are detected by ["PVD", ["brewery_name", "&"]].
# 78 cells are detected by ["PVD", ["brewery_name", "E"]].
# 4782 cells are detected by ["RVD", ["style", "city"]].
# 302 cells are detected by ["PVD", ["city", "p"]].
# 68 cells are detected by ["PVD", ["state", "D"]].
# 86 cells are detected by ["PVD", ["brewery_name", "K"]].
# 213 cells are detected by ["PVD", ["style", "p"]].
# 711 cells are detected by ["PVD", ["beer_name", "u"]].
# 4532 cells are detected by ["RVD", ["city", "index"]].
# 176 cells are detected by ["PVD", ["brewery_name", "H"]].
# 21951 cells are detected by ["OD", ["histogram", "0.1", "0.9"]].
# 180 cells are detected by ["PVD", ["beer_name", "O"]].
# 4424 cells are detected by ["RVD", ["brewery_id", "ounces"]].330 cells are detected by ["PVD", ["beer_name", "b"]].
#
# 11 cells are detected by ["PVD", ["ounces", "S"]].10 cells are detected by ["PVD", ["beer_name", "!"]].
#
# 1319 cells are detected by ["PVD", ["beer_name", "n"]].
# 188 cells are detected by ["PVD", ["ibu", "8"]].
# 1476 cells are detected by ["OD", ["gaussian", "2.3"]].
# 5 cells are detected by ["PVD", ["brewery_name", "7"]].
# 1 cells are detected by ["PVD", ["city", "Z"]].
# 503 cells are detected by ["PVD", ["brewery_id", "0"]].
# 246 cells are detected by ["PVD", ["beer_name", "0"]].
# 53 cells are detected by ["PVD", ["state", "S"]].
# 54 cells are detected by ["PVD", ["style", "G"]].
# 46 cells are detected by ["PVD", ["style", "K"]].
# 612 cells are detected by ["PVD", ["id", "0"]].
# 129 cells are detected by ["PVD", ["ounces", "A"]].
# 28 cells are detected by ["PVD", ["beer_name", "Y"]].
# 416 cells are detected by ["PVD", ["beer_name", "p"]].
# 699 cells are detected by ["PVD", ["ounces", "e"]].
# 9061 cells are detected by ["OD", ["histogram", "0.1", "0.5"]].
# 2188 cells are detected by ["PVD", ["style", "i"]].
# 4580 cells are detected by ["RVD", ["brewery_name", "id"]].
# 2055 cells are detected by ["PVD", ["brewery_name", "y"]].
# 3 cells are detected by ["PVD", ["beer_name", "\u00b0"]].
# 1130 cells are detected by ["PVD", ["beer_name", "A"]].
# 470 cells are detected by ["PVD", ["brewery_id", "6"]].
# 408 cells are detected by ["PVD", ["style", "h"]].
# 418 cells are detected by ["PVD", ["brewery_id", "7"]].
# 0 cells are detected by ["RVD", ["brewery_id", "brewery_name"]].
# 2378 cells are detected by ["RVD", ["city", "brewery_name"]].
# 129 cells are detected by ["PVD", ["ounces", "k"]].
# 1669 cells are detected by ["PVD", ["brewery_name", "C"]].
# 2115 cells are detected by ["PVD", ["style", "r"]].
# 4810 cells are detected by ["RVD", ["ounces", "brewery_name"]].
# 55 cells are detected by ["PVD", ["beer_name", "V"]].
# 583 cells are detected by ["PVD", ["style", "t"]].
# 0 cells are detected by ["RVD", ["index", "brewery_id"]].
# 4668 cells are detected by ["RVD", ["abv", "index"]].
# 1513 cells are detected by ["PVD", ["style", "l"]].
# 43 cells are detected by ["PVD", ["beer_name", "."]].
# 916 cells are detected by ["PVD", ["beer_name", "s"]].
# 657 cells are detected by ["PVD", ["city", " "]].
# 76 cells are detected by ["PVD", ["style", "f"]].
# 211 cells are detected by ["PVD", ["style", "R"]].
# 588 cells are detected by ["PVD", ["state", "A"]].
# 204 cells are detected by ["PVD", ["beer_name", "G"]].
# 1 cells are detected by ["PVD", ["style", "q"]].
# 1964 cells are detected by ["PVD", ["style", "n"]].
# 1295 cells are detected by ["OD", ["histogram", "0.7", "0.1"]].
# 4502 cells are detected by ["OD", ["histogram", "0.9", "0.3"]].6 cells are detected by ["PVD", ["beer_name", ":"]].
#
# 182 cells are detected by ["PVD", ["style", "D"]].
# 1673 cells are detected by ["PVD", ["brewery_name", "g"]].
# 46 cells are detected by ["PVD", ["state", "Z"]].
# 297 cells are detected by ["PVD", ["city", "v"]].
# 2403 cells are detected by ["PVD", ["brewery_name", "e"]].
# 24 cells are detected by ["RVD", ["beer_name", "style"]].
# 16 cells are detected by ["PVD", ["ounces", "9"]].
# 126 cells are detected by ["PVD", ["city", "G"]].
# 144 cells are detected by ["RVD", ["beer_name", "city"]].
# 0 cells are detected by ["RVD", ["id", "brewery_id"]].
# 12 cells are detected by ["PVD", ["beer_name", "j"]].
# 473 cells are detected by ["PVD", ["style", "b"]].
# 0 cells are detected by ["RVD", ["index", "ounces"]].
# 2 cells are detected by ["PVD", ["beer_name", ","]].
# 145 cells are detected by ["PVD", ["brewery_name", "O"]].
# 4810 cells are detected by ["RVD", ["ounces", "beer_name"]].
# 1 cells are detected by ["PVD", ["ounces", "8"]].
# 5388 cells are detected by ["OD", ["histogram", "0.3", "0.3"]].
# 0 cells are detected by ["RVD", ["index", "brewery_name"]].
# 129 cells are detected by ["PVD", ["ounces", "T"]].0 cells are detected by ["RVD", ["index", "city"]].
#
# 953 cells are detected by ["PVD", ["index", "2"]].
# 4450 cells are detected by ["RVD", ["city", "abv"]].
# 244 cells are detected by ["PVD", ["city", "A"]].
# 429 cells are detected by ["PVD", ["brewery_name", "S"]].
# 92 cells are detected by ["PVD", ["beer_name", "z"]].
# 30 cells are detected by ["PVD", ["beer_name", "6"]].
# 1732 cells are detected by ["RVD", ["brewery_id", "city"]].
# 120 cells are detected by ["PVD", ["brewery_name", "'"]].
# 3 cells are detected by ["PVD", ["beer_name", "\u2122"]].
# 0 cells are detected by ["RVD", ["index", "ibu"]].
# 0 cells are detected by ["RVD", ["id", "index"]].
# 14 cells are detected by ["RVD", ["brewery_name", "state"]].
# 7 cells are detected by ["PVD", ["city", "-"]].
# 2159 cells are detected by ["OD", ["gaussian", "1.7"]].
# 315 cells are detected by ["PVD", ["brewery_name", "c"]].
# 13 cells are detected by ["PVD", ["beer_name", "#"]].
# 150 cells are detected by ["PVD", ["brewery_name", "b"]].
# 4424 cells are detected by ["RVD", ["city", "ounces"]].
# 29 cells are detected by ["PVD", ["brewery_name", "J"]].
# 11 cells are detected by ["PVD", ["beer_name", "Z"]].
# 129 cells are detected by ["PVD", ["ounces", "m"]].
# 479 cells are detected by ["PVD", ["beer_name", "I"]].
# 0 cells are detected by ["RVD", ["index", "beer_name"]].
# 5 cells are detected by ["PVD", ["brewery_name", "\u00f6"]].
# 1181 cells are detected by ["PVD", ["beer_name", "t"]].
# 103 cells are detected by ["PVD", ["style", "C"]].
# 4526 cells are detected by ["RVD", ["state", "brewery_name"]].
# 4802 cells are detected by ["RVD", ["ounces", "ibu"]].
# 4632 cells are detected by ["RVD", ["abv", "style"]].
# 410 cells are detected by ["PVD", ["style", "d"]].
# 33 cells are detected by ["PVD", ["brewery_name", "z"]].
# 4810 cells are detected by ["RVD", ["ounces", "abv"]].
# 536 cells are detected by ["PVD", ["city", "d"]].
# 2937 cells are detected by ["OD", ["gaussian", "1.5"]].
# 123 cells are detected by ["PVD", ["state", "X"]].
# 0 cells are detected by ["RVD", ["id", "beer_name"]].
# 2392 cells are detected by ["RVD", ["city", "brewery_id"]].
# 1 cells are detected by ["PVD", ["beer_name", "\u2018"]].
# 4656 cells are detected by ["RVD", ["abv", "brewery_name"]].
# 113 cells are detected by ["PVD", ["city", "H"]].
# 63 cells are detected by ["PVD", ["brewery_name", "."]].
# 4562 cells are detected by ["RVD", ["state", "ounces"]].
# 4778 cells are detected by ["RVD", ["ibu", "brewery_id"]].
# 219 cells are detected by ["PVD", ["brewery_name", "R"]].
# 4656 cells are detected by ["RVD", ["abv", "beer_name"]].
# 698 cells are detected by ["PVD", ["style", "o"]].
# 225 cells are detected by ["PVD", ["ibu", "4"]].
# 1567 cells are detected by ["PVD", ["ounces", "2"]].
# 699 cells are detected by ["PVD", ["ounces", "u"]].
# 16260 cells are detected by ["OD", ["histogram", "0.5", "0.7"]].
# 227 cells are detected by ["PVD", ["beer_name", "w"]].
# 160 cells are detected by ["PVD", ["style", "L"]].
# 5388 cells are detected by ["OD", ["histogram", "0.5", "0.3"]].
# 15 cells are detected by ["PVD", ["city", "."]].
# 244 cells are detected by ["PVD", ["brewery_name", "A"]].
# 4810 cells are detected by ["RVD", ["ounces", "city"]].
# 36 cells are detected by ["PVD", ["city", "V"]].
# 511 strategy profiles are collected.
# 44 Features are generated for column 0.
# 44 Features are generated for column 1.
# 133 Features are generated for column 2.
# 100 Features are generated for column 3.
# 63 Features are generated for column 4.
# 54 Features are generated for column 5.
# 54 Features are generated for column 6.
# 55 Features are generated for column 7.
# 103 Features are generated for column 8.
# 106 Features are generated for column 9.
# 75 Features are generated for column 10.
# A hierarchical clustering model is built for column 0.
# A hierarchical clustering model is built for column 1.
# A hierarchical clustering model is built for column 2.
# A hierarchical clustering model is built for column 3.
# A hierarchical clustering model is built for column 4.
# A hierarchical clustering model is built for column 5.
# A hierarchical clustering model is built for column 6.
# A hierarchical clustering model is built for column 7.
# A hierarchical clustering model is built for column 8.
# A hierarchical clustering model is built for column 9.
# A hierarchical clustering model is built for column 10.

# %% [markdown]
# ## 4. Interactive Tuple Sampling and Labeling
# Raha then iteratively samples a tuple. We should label data cells of each sampled tuple.

# %%
def on_button_clicked(_):
    for j in range(0, len(texts)):
        cell = (d.sampled_tuple, j)
        error_label = 0
        correction = texts[j].value
        if d.dataframe.iloc[cell] != correction:
            error_label = 1
        d.labeled_cells[cell] = [error_label, correction]
    d.labeled_tuples[d.sampled_tuple] = 1

app_1.sample_tuple(d)
print("Fix the dirty cells in the following sampled tuple.")
sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
IPython.display.display(sampled_tuple)  
texts = [ipywidgets.Text(value=d.dataframe.iloc[d.sampled_tuple, j]) for j in range(d.dataframe.shape[1])]
button = ipywidgets.Button(description="Save the Annotation")
button.on_click(on_button_clicked)
output = ipywidgets.VBox(children=texts + [button])
IPython.display.display(output)
# Out:
# Tuple 630 is sampled.
# Fix the dirty cells in the following sampled tuple.
#     index provider_number                                 name  \
# 630   631           10029  east alabama medical center and snf
#
#                   address_1 address_2 address_3     city state    zip county  \
# 630  2000 pepperell parkway     empty     empty  opelika    al  36801    lee
#
#           phone                  type  \
# 630  3347493411  acute care hospitals
#
#                                            owner emergency_service  condition  \
# 630  government - hospital district or authority               yes  pneumonia
#
#     measure_code                                       measure_name score  \
# 630        pn-5c  pneumonia patients given initial antibiotic(s)...   96%
#
#            sample state_average
# 630  153 patients      al_pn-5c
# VBox(children=(Text(value='631'), Text(value='10029'), Text(value='east alabama medical center and snf'), Text…

# %% [markdown]
# For the sake of time, we use the ground truth of the dataset to label tuples below.

# %%
# %%capture
while len(d.labeled_tuples) < app_1.LABELING_BUDGET:
    app_1.sample_tuple(d)
    if d.has_ground_truth:
        app_1.label_with_ground_truth(d)

# %% [markdown]
# ## 5. Propagating User Labels and Predicting the Labels
# Raha then propagates each user label through its cluster. Raha then trains and applies one classifier per data column to predict the label of the rest of data cells.

# %%
app_1.propagate_labels(d)
app_1.predict_labels(d)
# Out:
# The number of labeled data cells increased from 220 to 24558.
# A classifier is trained and applied on column 0.
# A classifier is trained and applied on column 1.
# A classifier is trained and applied on column 2.
# A classifier is trained and applied on column 3.
# A classifier is trained and applied on column 4.
# A classifier is trained and applied on column 5.
# A classifier is trained and applied on column 6.
# A classifier is trained and applied on column 7.
# A classifier is trained and applied on column 8.
# A classifier is trained and applied on column 9.
# A classifier is trained and applied on column 10.

# %% [markdown]
# ## 6. Initializing and Updating the Error Corrector Models
# Baran initializes the error corrector models. Baran then iteratively samples a tuple. We should label data cells of each sampled tuple. It then udpates the models accordingly and generates a feature vector for each pair of a data error and a correction candidate. Finally, it trains and applies a classifier to each data column to predict the final correction of each data error. Since we already labeled tuples for Raha, we use the same labeled tuples and do not label new tuples here.

# %%
app_2.initialize_models(d)
app_2.initialize_dataset(d)
for si in d.labeled_tuples:
    d.sampled_tuple = si
    app_2.update_models(d)
    app_2.generate_features(d)
    app_2.predict_corrections(d)
# Out:
# The error corrector models are initialized.
# The error corrector models are updated with new labeled tuple 869.
# 215102 pairs of (a data error, a potential correction) are featurized.
# 65% (2845 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 310.
# 215311 pairs of (a data error, a potential correction) are featurized.
# 71% (3113 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1624.
# 215311 pairs of (a data error, a potential correction) are featurized.
# 71% (3115 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1837.
# 217192 pairs of (a data error, a potential correction) are featurized.
# 71% (3115 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1985.
# 218205 pairs of (a data error, a potential correction) are featurized.
# 94% (4116 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1312.
# 218205 pairs of (a data error, a potential correction) are featurized.
# 94% (4116 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1969.
# 218205 pairs of (a data error, a potential correction) are featurized.
# 94% (4116 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 836.
# 218340 pairs of (a data error, a potential correction) are featurized.
# 94% (4125 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 757.
# 218340 pairs of (a data error, a potential correction) are featurized.
# 94% (4127 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 487.
# 218340 pairs of (a data error, a potential correction) are featurized.
# 94% (4127 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1486.
# 218346 pairs of (a data error, a potential correction) are featurized.
# 95% (4138 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2358.
# 218346 pairs of (a data error, a potential correction) are featurized.
# 95% (4138 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2390.
# 218352 pairs of (a data error, a potential correction) are featurized.
# 95% (4150 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 697.
# 218352 pairs of (a data error, a potential correction) are featurized.
# 95% (4150 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 367.
# 218352 pairs of (a data error, a potential correction) are featurized.
# 95% (4152 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 90.
# 218490 pairs of (a data error, a potential correction) are featurized.
# 96% (4194 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1384.
# 218490 pairs of (a data error, a potential correction) are featurized.
# 96% (4204 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1554.
# 220896 pairs of (a data error, a potential correction) are featurized.
# 96% (4204 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2394.
# 220896 pairs of (a data error, a potential correction) are featurized.
# 96% (4204 / 4369) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1898.
# 220899 pairs of (a data error, a potential correction) are featurized.
# 96% (4216 / 4369) of data errors are corrected.

# %% [markdown]
# ## 7. Storing Results
# Both Raha and Baran can also store the error detection/correction results.

# %%
app_1.store_results(d)
app_2.store_results(d)
# Out:
# The results are stored in datasets/beers/raha-baran-results-beers/error-detection/detection.dataset.
# The results are stored in datasets/beers/raha-baran-results-beers/error-correction/correction.dataset.

# %% [markdown]
# ## 8. Evaluating the Data Cleaning Task
# We can finally evaluate our data cleaning task.

# %%
edp, edr, edf = d.get_data_cleaning_evaluation(d.detected_cells)[:3]
ecp, ecr, ecf = d.get_data_cleaning_evaluation(d.corrected_cells)[-3:]

evaluation_df = pandas.DataFrame(columns=["Task", "Precision", "Recall", "F1 Score"])
evaluation_df = evaluation_df.append({"Task": "Error Detection (Raha)", "Precision": "{:.2f}".format(edp), 
                                      "Recall": "{:.2f}".format(edr), "F1 Score": "{:.2f}".format(edf)}, ignore_index=True)
evaluation_df = evaluation_df.append({"Task": "Error Correction (Baran)", "Precision": "{:.2f}".format(ecp), 
                                      "Recall": "{:.2f}".format(ecr), "F1 Score": "{:.2f}".format(ecf)}, ignore_index=True)
evaluation_df.head()
# Out:
#                        Task Precision Recall F1 Score
# 0    Error Detection (Raha)      1.00   1.00     1.00
# 1  Error Correction (Baran)      0.78   0.75     0.77
