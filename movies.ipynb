# %% [markdown]
# # End-to-End Data Cleaning Pipeline with Raha and Baran (Minimal and Integrated)
# We build an end-to-end data cleaning pipeline with our configuration-free error detection and correction systems, Raha and Baran.

# %%
import pandas
import IPython.display
import ipywidgets

import raha

# %% [markdown]
# ## 1. Instantiating the Detection and Correction Classes
# We first instantiate the `Detection` and `Correction` classes.

# %%
from raha import analysis_utilities
app_1 = raha.Detection()
app_2 = raha.Correction()

# How many tuples would you label?
app_1.LABELING_BUDGET = 20
app_2.LABELING_BUDGET = 0

# Would you like to see the logs?
app_1.VERBOSE = True
app_2.VERBOSE = True

# %% [markdown]
# ## 2. Instantiating the Dataset
# We next load and instantiate the dataset object.

# %%
dataset_dictionary = {
        "name": "movies_1",
        "path": "datasets/movies_1/dirty.csv",
        "clean_path": "datasets/movies_1/clean.csv"
    }
d = app_1.initialize_dataset(dataset_dictionary)
d.dataframe.head()
# Out:
#           id                         name  year            release_date  \
# 0  tt0054215                       Psycho  1960  8 September 1960 (USA)
# 1  tt0088993              Day of the Dead  1985      19 July 1985 (USA)
# 2  tt0032484        Foreign Correspondent  1940    16 August 1940 (USA)
# 3  tt0889671                       Trumbo  2007      27 June 2008 (USA)
# 4  tt1325014  The People vs. George Lucas  2010    29 August 2011 (USA)
#
#                 director                                creator  \
# 0       Alfred Hitchcock            Joseph Stefano,Robert Bloch
# 1       George A. Romero                       George A. Romero
# 2       Alfred Hitchcock          Charles Bennett,Joan Harrison
# 3            Peter Askin  Christopher Trumbo,Christopher Trumbo
# 4  Alexandre O. Philippe                  Alexandre O. Philippe
#
#                                         actors  \
# 0       Anthony Perkins,Janet Leigh,Vera Miles
# 1  Lori Cardille,Terry Alexander,Joseph Pilato
# 2     Joel McCrea,Laraine Day,Herbert Marshall
# 3       Dalton Trumbo,Joan Allen,Brian Dennehy
# 4       Joe Nussbaum,Daryl Frazetti,Doug Jones
#
#                                            full_cast               language  \
# 0  Anthony Perkins,Vera Miles,John Gavin,Janet Le...                English
# 1  Lori Cardille,Terry Alexander,Joseph Pilato,Ja...                English
# 2  Joel McCrea,Laraine Day,Herbert Marshall,Georg...  English,Dutch,Latvian
# 3  Dalton Trumbo,Joan Allen,Brian Dennehy,Michael...                English
# 4  Joe Nussbaum,Daryl Frazetti,Doug Jones,Damian ...         English,French
#
#   country duration rating_value rating_count         review_count  \
# 0     USA  109 min          8.6      379,998  976 user,290 critic
# 1     USA   96 min          7.2       46,421  414 user,177 critic
# 2     USA  120 min          7.6       12,684   124 user,73 critic
# 3     USA   96 min          7.5          724    14 user,33 critic
# 4  USA,UK   93 min          6.7        3,341    27 user,49 critic
#
#                      genre                                  filming_locations  \
# 0  Horror,Mystery,Thriller  Title and Trust Building, 114 West Adams Stree...
# 1      Action,Drama,Horror                       Sanibel Island, Florida, USA
# 2     Romance,Thriller,War  Hotel de l'Europe, Nieuwe Doelenstraat 2-14, A...
# 3    Documentary,Biography
# 4       Documentary,Comedy              Geneva, Canton de Genève, Switzerland
#
#                                          description
# 0  A Phoenix secretary steals $40,000 from her em...
# 1  A small group of military officers and scienti...
# 2  On the eve of WWII, a young American reporter ...
# 3  Through a focus on the life of Dalton Trumbo (...
# 4  An examination of the widespread fan disenchan...

# %% [markdown]
# ## 3. Generating Features and Clusters
# Raha runs (all or the promising) error detection strategies on the dataset. This step could take a while because all the strategies should be run on the dataset. Raha then generates a feature vector for each data cell based on the output of error detection strategies. Raha next builds a hierarchical clustering model for our clustering-based sampling approach.

# %%
app_1.run_strategies(d)
app_1.generate_features(d)
app_1.build_clusters(d)
# Out:
# I just load strategies' results as they have already been run on the dataset!
# 1246 strategy profiles are collected.
# 88 Features are generated for column 0.
# 149 Features are generated for column 1.
# 76 Features are generated for column 2.
# 123 Features are generated for column 3.
# 144 Features are generated for column 4.
# 143 Features are generated for column 5.
# 149 Features are generated for column 6.
# 158 Features are generated for column 7.
# 119 Features are generated for column 8.
# 97 Features are generated for column 9.
# 67 Features are generated for column 10.
# 78 Features are generated for column 11.
# 63 Features are generated for column 12.
# 71 Features are generated for column 13.
# 104 Features are generated for column 14.
# 152 Features are generated for column 15.
# 162 Features are generated for column 16.
# A hierarchical clustering model is built for column 0.
# A hierarchical clustering model is built for column 1.
# A hierarchical clustering model is built for column 2.
# A hierarchical clustering model is built for column 3.
# A hierarchical clustering model is built for column 4.
# A hierarchical clustering model is built for column 5.
# A hierarchical clustering model is built for column 6.
# A hierarchical clustering model is built for column 7.
# A hierarchical clustering model is built for column 8.
# A hierarchical clustering model is built for column 9.
# A hierarchical clustering model is built for column 10.
# A hierarchical clustering model is built for column 11.
# A hierarchical clustering model is built for column 12.
# A hierarchical clustering model is built for column 13.
# A hierarchical clustering model is built for column 14.
# A hierarchical clustering model is built for column 15.
# A hierarchical clustering model is built for column 16.

# %% [markdown]
# ## 4. Interactive Tuple Sampling and Labeling
# Raha then iteratively samples a tuple. We should label data cells of each sampled tuple.

# %%
# def on_button_clicked(_):
#     for j in range(0, len(texts)):
#         cell = (d.sampled_tuple, j)
#         error_label = 0
#         correction = texts[j].value
#         if d.dataframe.iloc[cell] != correction:
#             error_label = 1
#         d.labeled_cells[cell] = [error_label, correction]
#     d.labeled_tuples[d.sampled_tuple] = 1
#
# app_1.sample_tuple(d)
# print("Fix the dirty cells in the following sampled tuple.")
# sampled_tuple = pandas.DataFrame(data=[d.dataframe.iloc[d.sampled_tuple, :]], columns=d.dataframe.columns)
# IPython.display.display(sampled_tuple)
# texts = [ipywidgets.Text(value=d.dataframe.iloc[d.sampled_tuple, j]) for j in range(d.dataframe.shape[1])]
# button = ipywidgets.Button(description="Save the Annotation")
# button.on_click(on_button_clicked)
# output = ipywidgets.VBox(children=texts + [button])
# IPython.display.display(output)

# %% [markdown]
# For the sake of time, we use the ground truth of the dataset to label tuples below.

# %%
# %%capture
while len(d.labeled_tuples) < app_1.LABELING_BUDGET:
    app_1.sample_tuple(d)
    if d.has_ground_truth:
        app_1.label_with_ground_truth(d)

# %% [markdown]
# ## 5. Propagating User Labels and Predicting the Labels
# Raha then propagates each user label through its cluster. Raha then trains and applies one classifier per data column to predict the label of the rest of data cells.

# %%
app_1.propagate_labels(d)
app_1.predict_labels(d)
# Out:
# The number of labeled data cells increased from 340 to 91959.
# A classifier is trained and applied on column 0.
# A classifier is trained and applied on column 1.
# A classifier is trained and applied on column 2.
# A classifier is trained and applied on column 3.
# A classifier is trained and applied on column 4.
# A classifier is trained and applied on column 5.
# A classifier is trained and applied on column 6.
# A classifier is trained and applied on column 7.
# A classifier is trained and applied on column 8.
# A classifier is trained and applied on column 9.
# A classifier is trained and applied on column 10.
# A classifier is trained and applied on column 11.
# A classifier is trained and applied on column 12.
# A classifier is trained and applied on column 13.
# A classifier is trained and applied on column 14.
# A classifier is trained and applied on column 15.
# A classifier is trained and applied on column 16.

# %% [markdown]
# ## 6. Initializing and Updating the Error Corrector Models
# Baran initializes the error corrector models. Baran then iteratively samples a tuple. We should label data cells of each sampled tuple. It then udpates the models accordingly and generates a feature vector for each pair of a data error and a correction candidate. Finally, it trains and applies a classifier to each data column to predict the final correction of each data error. Since we already labeled tuples for Raha, we use the same labeled tuples and do not label new tuples here.

# %%
app_2.initialize_models(d)
app_2.initialize_dataset(d)
for si in d.labeled_tuples:
    d.sampled_tuple = si
    app_2.update_models(d)
    app_2.generate_features(d)
    app_2.predict_corrections(d)
# Out:
# The error corrector models are initialized.
# The error corrector models are updated with new labeled tuple 1545.
# 20364593 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: No train 0
#     Column 2: Train
#     Column 3: Train
#     Column 5: No train 0
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: No train 0
# Train sizes in this step:
#     Column 0: 36025
#     Column 2: 535
#     Column 3: 23575
#     Column 4: 3745
#     Column 5: 21752
#     Column 10: 810
#     Column 11: 588
#     Column 12: 8300
#     Column 14: 2548
#     Column 16: 31150
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 95 Real changes: 95
#     Column 3: 0 Real changes: 0
#     Column 5: 0 Real changes: 0
#     Column 10: 144 Real changes: 144
#     Column 11: 156 Real changes: 156
#     Column 12: 2426 Real changes: 2426
#     Column 14: 45 Real changes: 45
#     Column 16: 0 Real changes: 0
# 31% (2879 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 6149.
# 20375363 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36030
#     Column 2: 535
#     Column 3: 23586
#     Column 4: 3745
#     Column 5: 21757
#     Column 10: 818
#     Column 11: 588
#     Column 12: 8314
#     Column 14: 2548
#     Column 16: 31158
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 166 Real changes: 164
#     Column 3: 79 Real changes: 79
#     Column 5: 9 Real changes: 9
#     Column 10: 140 Real changes: 61
#     Column 11: 141 Real changes: 32
#     Column 12: 4437 Real changes: 2011
#     Column 14: 29 Real changes: 6
#     Column 16: 9 Real changes: 9
# 55% (5103 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 6005.
# 20375363 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36030
#     Column 2: 535
#     Column 3: 23586
#     Column 4: 3745
#     Column 5: 21757
#     Column 10: 818
#     Column 11: 588
#     Column 12: 8314
#     Column 14: 2548
#     Column 16: 31158
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 166 Real changes: 0
#     Column 3: 77 Real changes: 2
#     Column 5: 130 Real changes: 130
#     Column 10: 140 Real changes: 36
#     Column 11: 144 Real changes: 21
#     Column 12: 4437 Real changes: 0
#     Column 14: 28 Real changes: 5
#     Column 16: 114 Real changes: 114
# 58% (5351 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 7098.
# 20375363 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36030
#     Column 2: 535
#     Column 3: 23586
#     Column 4: 3745
#     Column 5: 21757
#     Column 10: 818
#     Column 11: 588
#     Column 12: 8314
#     Column 14: 2548
#     Column 16: 31158
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 173 Real changes: 9
#     Column 3: 69 Real changes: 0
#     Column 5: 130 Real changes: 0
#     Column 10: 152 Real changes: 51
#     Column 11: 144 Real changes: 16
#     Column 12: 4437 Real changes: 0
#     Column 14: 27 Real changes: 4
#     Column 16: 0 Real changes: 0
# 58% (5354 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 6627.
# 20375363 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36030
#     Column 2: 535
#     Column 3: 23586
#     Column 4: 3745
#     Column 5: 21757
#     Column 10: 818
#     Column 11: 588
#     Column 12: 8314
#     Column 14: 2548
#     Column 16: 31158
# Corrections applied in this step:
#     Column 0: 2 Real changes: 2
#     Column 2: 163 Real changes: 0
#     Column 3: 74 Real changes: 67
#     Column 5: 9 Real changes: 0
#     Column 10: 140 Real changes: 48
#     Column 11: 142 Real changes: 19
#     Column 12: 4437 Real changes: 0
#     Column 14: 29 Real changes: 6
#     Column 16: 0 Real changes: 0
# 58% (5357 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2063.
# 20384283 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36038
#     Column 2: 535
#     Column 3: 23592
#     Column 4: 3745
#     Column 5: 21761
#     Column 10: 818
#     Column 11: 597
#     Column 12: 8324
#     Column 14: 2555
#     Column 16: 31166
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 181 Real changes: 15
#     Column 3: 142 Real changes: 132
#     Column 5: 21 Real changes: 13
#     Column 10: 99 Real changes: 65
#     Column 11: 369 Real changes: 345
#     Column 12: 4437 Real changes: 0
#     Column 14: 25 Real changes: 2
#     Column 16: 0 Real changes: 0
# 60% (5531 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2753.
# 20389776 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36038
#     Column 2: 535
#     Column 3: 23592
#     Column 4: 3745
#     Column 5: 21761
#     Column 10: 818
#     Column 11: 597
#     Column 12: 8334
#     Column 14: 2555
#     Column 16: 31166
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 181 Real changes: 6
#     Column 3: 77 Real changes: 67
#     Column 5: 21 Real changes: 0
#     Column 10: 99 Real changes: 33
#     Column 11: 375 Real changes: 237
#     Column 12: 4437 Real changes: 0
#     Column 14: 25 Real changes: 0
#     Column 16: 114 Real changes: 0
# 60% (5532 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 3058.
# 20389776 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36038
#     Column 2: 535
#     Column 3: 23592
#     Column 4: 3745
#     Column 5: 21761
#     Column 10: 818
#     Column 11: 597
#     Column 12: 8334
#     Column 14: 2555
#     Column 16: 31166
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 181 Real changes: 6
#     Column 3: 79 Real changes: 4
#     Column 5: 9 Real changes: 0
#     Column 10: 100 Real changes: 33
#     Column 11: 382 Real changes: 243
#     Column 12: 4437 Real changes: 0
#     Column 14: 25 Real changes: 0
#     Column 16: 0 Real changes: 0
# 60% (5538 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 5499.
# 20395780 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36038
#     Column 2: 535
#     Column 3: 23592
#     Column 4: 3745
#     Column 5: 21761
#     Column 10: 818
#     Column 11: 604
#     Column 12: 8344
#     Column 14: 2555
#     Column 16: 31166
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 181 Real changes: 6
#     Column 3: 103 Real changes: 55
#     Column 5: 2 Real changes: 2
#     Column 10: 99 Real changes: 32
#     Column 11: 333 Real changes: 209
#     Column 12: 4437 Real changes: 0
#     Column 14: 25 Real changes: 0
#     Column 16: 0 Real changes: 0
# 60% (5541 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2738.
# 20404256 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36045
#     Column 2: 535
#     Column 3: 23602
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 818
#     Column 11: 605
#     Column 12: 8354
#     Column 14: 2555
#     Column 16: 31174
# Corrections applied in this step:
#     Column 0: 2 Real changes: 2
#     Column 2: 208 Real changes: 35
#     Column 3: 77 Real changes: 2
#     Column 5: 130 Real changes: 2
#     Column 10: 6 Real changes: 1
#     Column 11: 59 Real changes: 6
#     Column 12: 4437 Real changes: 0
#     Column 14: 25 Real changes: 0
#     Column 16: 0 Real changes: 0
# 60% (5546 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 4321.
# 20409749 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36045
#     Column 2: 535
#     Column 3: 23602
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 818
#     Column 11: 605
#     Column 12: 8364
#     Column 14: 2555
#     Column 16: 31174
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 206 Real changes: 48
#     Column 3: 77 Real changes: 2
#     Column 5: 2 Real changes: 1
#     Column 10: 6 Real changes: 1
#     Column 11: 55 Real changes: 0
#     Column 12: 4437 Real changes: 0
#     Column 14: 25 Real changes: 0
#     Column 16: 0 Real changes: 0
# 60% (5546 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1658.
# 20411086 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36052
#     Column 2: 535
#     Column 3: 23603
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 821
#     Column 11: 605
#     Column 12: 8364
#     Column 14: 2557
#     Column 16: 31182
# Corrections applied in this step:
#     Column 0: 6 Real changes: 4
#     Column 2: 181 Real changes: 23
#     Column 3: 1 Real changes: 1
#     Column 5: 130 Real changes: 1
#     Column 10: 1 Real changes: 0
#     Column 11: 58 Real changes: 9
#     Column 12: 4437 Real changes: 0
#     Column 14: 38 Real changes: 14
#     Column 16: 0 Real changes: 0
# 60% (5562 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1755.
# 20411086 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36052
#     Column 2: 535
#     Column 3: 23603
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 821
#     Column 11: 605
#     Column 12: 8364
#     Column 14: 2557
#     Column 16: 31182
# Corrections applied in this step:
#     Column 0: 1 Real changes: 1
#     Column 2: 181 Real changes: 0
#     Column 3: 0 Real changes: 0
#     Column 5: 11 Real changes: 10
#     Column 10: 2 Real changes: 2
#     Column 11: 64 Real changes: 22
#     Column 12: 4437 Real changes: 0
#     Column 14: 37 Real changes: 2
#     Column 16: 1 Real changes: 1
# 60% (5572 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 4004.
# 20416579 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36052
#     Column 2: 535
#     Column 3: 23603
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 821
#     Column 11: 605
#     Column 12: 8374
#     Column 14: 2557
#     Column 16: 31182
# Corrections applied in this step:
#     Column 0: 6 Real changes: 1
#     Column 2: 183 Real changes: 1
#     Column 3: 1 Real changes: 0
#     Column 5: 9 Real changes: 0
#     Column 10: 25 Real changes: 25
#     Column 11: 53 Real changes: 2
#     Column 12: 4437 Real changes: 0
#     Column 14: 37 Real changes: 2
#     Column 16: 9 Real changes: 1
# 61% (5588 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 3486.
# 20416579 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36052
#     Column 2: 535
#     Column 3: 23603
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 821
#     Column 11: 605
#     Column 12: 8374
#     Column 14: 2557
#     Column 16: 31182
# Corrections applied in this step:
#     Column 0: 0 Real changes: 0
#     Column 2: 182 Real changes: 0
#     Column 3: 0 Real changes: 0
#     Column 5: 9 Real changes: 0
#     Column 10: 24 Real changes: 0
#     Column 11: 52 Real changes: 2
#     Column 12: 4437 Real changes: 0
#     Column 14: 38 Real changes: 2
#     Column 16: 9 Real changes: 0
# 61% (5588 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 6288.
# 20422072 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36052
#     Column 2: 535
#     Column 3: 23603
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 821
#     Column 11: 605
#     Column 12: 8384
#     Column 14: 2557
#     Column 16: 31182
# Corrections applied in this step:
#     Column 0: 6 Real changes: 0
#     Column 2: 182 Real changes: 0
#     Column 3: 2 Real changes: 2
#     Column 5: 130 Real changes: 2
#     Column 10: 0 Real changes: 0
#     Column 11: 48 Real changes: 25
#     Column 12: 4437 Real changes: 0
#     Column 14: 37 Real changes: 2
#     Column 16: 0 Real changes: 0
# 61% (5593 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 3751.
# 20427565 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36052
#     Column 2: 535
#     Column 3: 23603
#     Column 4: 3745
#     Column 5: 21765
#     Column 10: 821
#     Column 11: 605
#     Column 12: 8394
#     Column 14: 2557
#     Column 16: 31182
# Corrections applied in this step:
#     Column 0: 6 Real changes: 0
#     Column 2: 182 Real changes: 0
#     Column 3: 2 Real changes: 0
#     Column 5: 21 Real changes: 1
#     Column 10: 2 Real changes: 0
#     Column 11: 215 Real changes: 179
#     Column 12: 4437 Real changes: 0
#     Column 14: 38 Real changes: 2
#     Column 16: 9 Real changes: 0
# 61% (5604 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 1338.
# 20435959 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36059
#     Column 2: 535
#     Column 3: 23608
#     Column 4: 3745
#     Column 5: 21769
#     Column 10: 824
#     Column 11: 605
#     Column 12: 8404
#     Column 14: 2557
#     Column 16: 31190
# Corrections applied in this step:
#     Column 0: 2 Real changes: 0
#     Column 2: 24 Real changes: 7
#     Column 3: 1 Real changes: 0
#     Column 5: 2 Real changes: 1
#     Column 10: 1 Real changes: 0
#     Column 11: 7 Real changes: 5
#     Column 12: 4437 Real changes: 0
#     Column 14: 2 Real changes: 1
#     Column 16: 0 Real changes: 0
# 61% (5605 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 3659.
# 20435959 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36059
#     Column 2: 535
#     Column 3: 23608
#     Column 4: 3745
#     Column 5: 21769
#     Column 10: 824
#     Column 11: 605
#     Column 12: 8404
#     Column 14: 2557
#     Column 16: 31190
# Corrections applied in this step:
#     Column 0: 2 Real changes: 0
#     Column 2: 24 Real changes: 0
#     Column 3: 0 Real changes: 0
#     Column 5: 21 Real changes: 0
#     Column 10: 1 Real changes: 0
#     Column 11: 3 Real changes: 2
#     Column 12: 6 Real changes: 6
#     Column 14: 0 Real changes: 0
#     Column 16: 1 Real changes: 0
# 61% (5611 / 9230) of data errors are corrected.
# The error corrector models are updated with new labeled tuple 2718.
# 20435959 pairs of (a data error, a potential correction) are featurized.
# Prediction Method in this step:
#     Column 0: Train
#     Column 2: Train
#     Column 3: Train
#     Column 5: Train
#     Column 10: Train
#     Column 11: Train
#     Column 12: Train
#     Column 14: Train
#     Column 16: Train
# Train sizes in this step:
#     Column 0: 36059
#     Column 2: 535
#     Column 3: 23608
#     Column 4: 3745
#     Column 5: 21769
#     Column 10: 824
#     Column 11: 605
#     Column 12: 8404
#     Column 14: 2557
#     Column 16: 31190
# Corrections applied in this step:
#     Column 0: 2 Real changes: 0
#     Column 2: 24 Real changes: 0
#     Column 3: 1 Real changes: 0
#     Column 5: 21 Real changes: 0
#     Column 10: 2 Real changes: 0
#     Column 11: 7 Real changes: 0
#     Column 12: 6 Real changes: 0
#     Column 14: 2 Real changes: 0
#     Column 16: 0 Real changes: 0
# 61% (5611 / 9230) of data errors are corrected.

# %% [markdown]
# ## 7. Storing Results
# Both Raha and Baran can also store the error detection/correction results.

# %%
#app_1.store_results(d)
#app_2.store_results(d)

# %% [markdown]
# ## 8. Evaluating the Data Cleaning Task
# We can finally evaluate our data cleaning task.

# %%
edp, edr, edf = d.get_data_cleaning_evaluation(d.detected_cells)[:3]
ecp, ecr, ecf = d.get_data_cleaning_evaluation(d.corrected_cells)[-3:]

evaluation_df = pandas.DataFrame(columns=["Task", "Precision", "Recall", "F1 Score"])
evaluation_df = evaluation_df.append({"Task": "Error Detection (Raha)", "Precision": "{:.2f}".format(edp), 
                                      "Recall": "{:.2f}".format(edr), "F1 Score": "{:.2f}".format(edf)}, ignore_index=True)
evaluation_df = evaluation_df.append({"Task": "Error Correction (Baran)", "Precision": "{:.2f}".format(ecp), 
                                      "Recall": "{:.2f}".format(ecr), "F1 Score": "{:.2f}".format(ecf)}, ignore_index=True)
evaluation_df.head()

# %%
import importlib
importlib.reload(analysis_utilities)

# %%
actual_errors = d.get_actual_errors_dictionary()

# %%
analysis_utilities.detection_evaluation(d, actual_errors)

# %%
correction_confidence_df = analysis_utilities.get_correction_confidence_df(d, actual_errors)

# %%
correction_confidence_df.shape[0]

# %%
(correction_confidence_df["confidence"] < 0.98).sum()

# %%
analysis_utilities.correction_confidence_distributions(correction_confidence_df)

# %%
f = analysis_utilities.correction_correctness_by_confidence(correction_confidence_df)
f.show()
